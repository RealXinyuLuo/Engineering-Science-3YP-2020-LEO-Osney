# %%
import datetime
import Date
import pandas as pd
import numpy as np
import Forecast
import Date
import Demand
import requests
import matplotlib.pyplot as plt
import Price

# %%
one = np.array(pd.read_csv('presentation1.csv',usecols=[1]))
two = np.array(pd.read_csv('presentation2.csv',usecols=[1]))
three = np.array(pd.read_csv('presentation3.csv',usecols=[1]))

# %%
fig, ax = plt.subplots(3,sharex=True, figsize=[25,9*1.5])

ax[0].plot(one)
ax[0].set_title('Import Profile - No Battery',fontsize=15)
ax[0].set_ylim(0, 600)
ax[1].plot(two)
ax[1].set_title('Import Profile - With Battery',fontsize=15)
ax[1].set_ylim(0, 600)
ax[2].plot(three)
ax[2].set_title('Import Profile - With SMART',fontsize=15)
ax[2].set_ylim(0, 600)
ax[2].set_xticks([d for d in range(15*24,365*24,732)])
ax[2].set_xticklabels(['January','February','March','April','May','June','July','August','September','October','November','December'])
# Out:
# [Text(0, 0, 'January'),
#  Text(0, 0, 'February'),
#  Text(0, 0, 'March'),
#  Text(0, 0, 'April'),
#  Text(0, 0, 'May'),
#  Text(0, 0, 'June'),
#  Text(0, 0, 'July'),
#  Text(0, 0, 'August'),
#  Text(0, 0, 'September'),
#  Text(0, 0, 'October'),
#  Text(0, 0, 'November'),
#  Text(0, 0, 'December')]

# %%
hi = np.array([d for d in range(10,20,2)])
hi
# Out:
# array([10, 12, 14, 16, 18])

# %%
30.5*24
# Out:
# 732.0
