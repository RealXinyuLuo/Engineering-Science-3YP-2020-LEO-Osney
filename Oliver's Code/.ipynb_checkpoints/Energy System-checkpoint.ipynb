# %%
import pandas as pd
import matplotlib.pyplot as plt
import Demand
import Solar
import Price

# %% [markdown]
# # input the date you want here

# %%
datewanted = "01/03/2019"    ###  month day year  ###

# %% [markdown]
# # input the date you want here

# %%
daywanted = Demand.getdaywanted(datewanted)
totaldemand = Demand.gettotaldemand(daywanted)
solarsupply = Solar.getsolarsupply(daywanted)
price = Price.getvariablesellprice(daywanted)
bigdata =pd.concat([totaldemand, solarsupply, price], axis=1)

# %%
bigdata['Net Demand'] = bigdata['Total Demand (kWh)']-bigdata['Total Supply (kWh)']
plt.plot(bigdata['Net Demand'])
plt.xlabel('Time throughout the day')
plt.ylabel('(kWh)')
plt.title('Net electricity demand (kWh) for '+datewanted)
plt.xticks((0,5,11,17,23),('00:00','06:00','12:00','18:00','23:00'))
# Out:
# ([<matplotlib.axis.XTick at 0x115b0ead0>,
#   <matplotlib.axis.XTick at 0x115b0e210>,
#   <matplotlib.axis.XTick at 0x11627fe50>,
#   <matplotlib.axis.XTick at 0x115af0d50>,
#   <matplotlib.axis.XTick at 0x1161cc390>],
#  <a list of 5 Text xticklabel objects>)

# %%
bigdata['Running Cost (£)'] = bigdata['Grid Price']*bigdata['Net Demand']
bigdata['Running Cost (£)'] = bigdata['Running Cost (£)'].clip(lower=0)
bigdata
# Out:
#        Total Demand (kWh)  Total Supply (kWh)  Grid Price  Net Demand  \
# 00:00              62.630                 0.0    0.114660      62.630
# 01:00              61.225                 0.0    0.134085      61.225
# 02:00              61.025                 0.0    0.116865      61.025
# 03:00              61.630                 0.0    0.103215      61.630
# 04:00              59.620                 0.0    0.095655      59.620
# 05:00              60.425                 0.0    0.095235      60.425
# 06:00              60.225                 0.0    0.095655      60.225
# 07:00              61.025                 0.0    0.088200      61.025
# 08:00              65.035                 8.0    0.092400      57.035
# 09:00              77.815                65.6    0.105105      12.215
# 10:00              92.395               131.2    0.116865     -38.805
# 11:00              92.595               163.2    0.114660     -70.605
# 12:00              89.465               172.8    0.114660     -83.335
# 13:00              88.765               136.0    0.123270     -47.235
# 14:00              93.575                62.4    0.123480      31.175
# 15:00              90.185                 8.0    0.100065      82.185
# 16:00              88.055                 0.0    0.243075      88.055
# 17:00              93.465                 0.0    0.302400      93.465
# 18:00              81.680                 0.0    0.302400      81.680
# 19:00              76.045                 0.0    0.136710      76.045
# 20:00              67.335                 0.0    0.121695      67.335
# 21:00              72.535                 0.0    0.107835      72.535
# 22:00              66.530                 0.0    0.092610      66.530
# 23:00              65.540                 0.0    0.105840      65.540
#
#        Running Cost (£)
# 00:00          7.181156
# 01:00          8.209354
# 02:00          7.131687
# 03:00          6.361140
# 04:00          5.702951
# 05:00          5.754575
# 06:00          5.760822
# 07:00          5.382405
# 08:00          5.270034
# 09:00          1.283858
# 10:00          0.000000
# 11:00          0.000000
# 12:00          0.000000
# 13:00          0.000000
# 14:00          3.849489
# 15:00          8.223842
# 16:00         21.403969
# 17:00         28.263816
# 18:00         24.700032
# 19:00         10.396112
# 20:00          8.194333
# 21:00          7.821812
# 22:00          6.161343
# 23:00          6.936754

# %%
bigdata['Running Cost (£)'].sum()
# Out:
# 183.989483475
