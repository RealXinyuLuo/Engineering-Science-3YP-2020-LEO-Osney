# %%
__version__ = '0.3'
import pandas as pd
import numpy as np

# %%
class price_profiles:
    def __init__(self,request_status):
        self.request_status = request_status
    
    def getProfiles(self):
        import_price1 = pd.read_csv('data/octopus_imprt_price_southern.csv', index_col=0,parse_dates=True,header = 0)
        export_price1 = pd.read_csv('data/octopus_export_price_southern.csv', index_col=0,parse_dates=True,header = 0)

        start_time = "2019-1-31 00:00:00"
        end_time = "2019-5-15 22:30:00"
        
        import_price2 =import_price1.loc[start_time:end_time]
        export_price2 =export_price1.loc[start_time:end_time]
        
        import_price3 = import_price2.between_time('09:00:00','16:30:00')
        export_price3 = export_price2.between_time('09:00:00','16:30:00')
        
        for column in import_price3 [['Import Rate (p/kWh)']]:
            import_price = import_price3[column] 
            import_price_value = import_price.values
            
        for column in export_price3 [['Outgoing Agile Rate (p/kWh)']]:
            export_price = export_price3[column]
            export_price_value = export_price.values 
            
        return import_price_value, export_price_value

# %%
class control_class:
    """
     Input
    ----
    request status from the buildings 
    
    Return
    ----
    a control signal
    """
    def __init__(self,request_status):
        self.request_status = request_status
        
    def signalGen(self,import_price_value,export_price_value):     
        T = len(import_price_value) 
        signal = np.zeros((T, 1))
        
        if self.request_status == 0:  
            for time,price in enumerate(import_price_value):
                if price < 9:       # Charge/Buys when price < Maximum_Buy_Price
                    signal[time] = 1
                else:
                    signal[time] = 0  # Set all other cases to "do nothing" first
                    
            for time,price in enumerate(export_price_value):
                if price > 10 :       # Discharge/Sells when price > Minimum_Sell_Price 
                    signal[time] = -1 # Corrects some cases to sell electricity 
                
        elif self.request_status == 1: 
            signal = np.zeros((T, 1))  # Always connected to the buildings in this verison 
                   
        return signal

# %%
request_status = 0

price_profiles1 = price_profiles(request_status)
import_price_value, export_price_value = price_profiles1.getProfiles()

signal = control_class(request_status)
signal1 = signal.signalGen(import_price_value, export_price_value)
signal1
# Out:
# array([[-1.],
#        [-1.],
#        [-1.],
#        ...,
#        [ 0.],
#        [-1.],
#        [-1.]])

# %%
for number in enumerate(signal1):
    print(number)
# Out:
# (0, array([-1.]))
# (1, array([-1.]))
# (2, array([-1.]))
# (3, array([-1.]))
# (4, array([-1.]))
# (5, array([-1.]))
# (6, array([-1.]))
# (7, array([-1.]))
# (8, array([-1.]))
# (9, array([-1.]))
# (10, array([-1.]))
# (11, array([-1.]))
# (12, array([-1.]))
# (13, array([-1.]))
# (14, array([-1.]))
# (15, array([-1.]))
# (16, array([-1.]))
# (17, array([-1.]))
# (18, array([-1.]))
# (19, array([-1.]))
# (20, array([-1.]))
# (21, array([-1.]))
# (22, array([-1.]))
# (23, array([-1.]))
# (24, array([-1.]))
# (25, array([-1.]))
# (26, array([-1.]))
# (27, array([-1.]))
# (28, array([-1.]))
# (29, array([-1.]))
# (30, array([-1.]))
# (31, array([-1.]))
# (32, array([-1.]))
# (33, array([-1.]))
# (34, array([-1.]))
# (35, array([-1.]))
# (36, array([-1.]))
# (37, array([-1.]))
# (38, array([-1.]))
# (39, array([-1.]))
# (40, array([-1.]))
# (41, array([-1.]))
# (42, array([-1.]))
# (43, array([-1.]))
# (44, array([-1.]))
# (45, array([-1.]))
# (46, array([-1.]))
# (47, array([-1.]))
# (48, array([-1.]))
# (49, array([-1.]))
# (50, array([-1.]))
# (51, array([-1.]))
# (52, array([-1.]))
# (53, array([-1.]))
# (54, array([-1.]))
# (55, array([-1.]))
# (56, array([-1.]))
# (57, array([-1.]))
# (58, array([-1.]))
# (59, array([-1.]))
# (60, array([-1.]))
# (61, array([-1.]))
# (62, array([-1.]))
# (63, array([-1.]))
# (64, array([-1.]))
# (65, array([-1.]))
# (66, array([-1.]))
# (67, array([-1.]))
# (68, array([-1.]))
# (69, array([-1.]))
# (70, array([-1.]))
# (71, array([-1.]))
# (72, array([-1.]))
# (73, array([-1.]))
# (74, array([-1.]))
# (75, array([-1.]))
# (76, array([-1.]))
# (77, array([-1.]))
# (78, array([-1.]))
# (79, array([-1.]))
# (80, array([-1.]))
# (81, array([-1.]))
# (82, array([-1.]))
# (83, array([-1.]))
# (84, array([-1.]))
# (85, array([-1.]))
# (86, array([-1.]))
# (87, array([-1.]))
# (88, array([-1.]))
# (89, array([-1.]))
# (90, array([-1.]))
# (91, array([-1.]))
# (92, array([-1.]))
# (93, array([-1.]))
# (94, array([-1.]))
# (95, array([-1.]))
# (96, array([-1.]))
# (97, array([-1.]))
# (98, array([-1.]))
# (99, array([-1.]))
# (100, array([-1.]))
# (101, array([-1.]))
# (102, array([-1.]))
# (103, array([-1.]))
# (104, array([-1.]))
# (105, array([-1.]))
# (106, array([-1.]))
# (107, array([-1.]))
# (108, array([-1.]))
# (109, array([-1.]))
# (110, array([-1.]))
# (111, array([-1.]))
# (112, array([-1.]))
# (113, array([-1.]))
# (114, array([-1.]))
# (115, array([-1.]))
# (116, array([-1.]))
# (117, array([-1.]))
# (118, array([-1.]))
# (119, array([-1.]))
# (120, array([-1.]))
# (121, array([-1.]))
# (122, array([-1.]))
# (123, array([-1.]))
# (124, array([-1.]))
# (125, array([-1.]))
# (126, array([-1.]))
# (127, array([-1.]))
# (128, array([-1.]))
# (129, array([-1.]))
# (130, array([-1.]))
# (131, array([-1.]))
# (132, array([-1.]))
# (133, array([-1.]))
# (134, array([-1.]))
# (135, array([-1.]))
# (136, array([-1.]))
# (137, array([-1.]))
# (138, array([-1.]))
# (139, array([-1.]))
# (140, array([-1.]))
# (141, array([-1.]))
# (142, array([-1.]))
# (143, array([-1.]))
# (144, array([-1.]))
# (145, array([-1.]))
# (146, array([-1.]))
# (147, array([-1.]))
# (148, array([-1.]))
# (149, array([-1.]))
# (150, array([-1.]))
# (151, array([-1.]))
# (152, array([-1.]))
# (153, array([-1.]))
# (154, array([-1.]))
# (155, array([-1.]))
# (156, array([0.]))
# (157, array([0.]))
# (158, array([-1.]))
# (159, array([-1.]))
# (160, array([-1.]))
# (161, array([-1.]))
# (162, array([-1.]))
# (163, array([-1.]))
# (164, array([-1.]))
# (165, array([-1.]))
# (166, array([-1.]))
# (167, array([-1.]))
# (168, array([-1.]))
# (169, array([-1.]))
# (170, array([-1.]))
# (171, array([-1.]))
# (172, array([-1.]))
# (173, array([-1.]))
# (174, array([-1.]))
# (175, array([-1.]))
# (176, array([-1.]))
# (177, array([-1.]))
# (178, array([-1.]))
# (179, array([-1.]))
# (180, array([-1.]))
# (181, array([-1.]))
# (182, array([-1.]))
# (183, array([-1.]))
# (184, array([-1.]))
# (185, array([-1.]))
# (186, array([-1.]))
# (187, array([-1.]))
# (188, array([-1.]))
# (189, array([-1.]))
# (190, array([-1.]))
# (191, array([-1.]))
# (192, array([-1.]))
# (193, array([-1.]))
# (194, array([-1.]))
# (195, array([-1.]))
# (196, array([-1.]))
# (197, array([-1.]))
# (198, array([-1.]))
# (199, array([0.]))
# (200, array([-1.]))
# (201, array([-1.]))
# (202, array([-1.]))
# (203, array([-1.]))
# (204, array([-1.]))
# (205, array([-1.]))
# (206, array([-1.]))
# (207, array([-1.]))
# (208, array([-1.]))
# (209, array([-1.]))
# (210, array([-1.]))
# (211, array([-1.]))
# (212, array([-1.]))
# (213, array([0.]))
# (214, array([0.]))
# (215, array([0.]))
# (216, array([0.]))
# (217, array([0.]))
# (218, array([0.]))
# (219, array([0.]))
# (220, array([0.]))
# (221, array([-1.]))
# (222, array([-1.]))
# (223, array([-1.]))
# (224, array([-1.]))
# (225, array([-1.]))
# (226, array([-1.]))
# (227, array([-1.]))
# (228, array([-1.]))
# (229, array([0.]))
# (230, array([0.]))
# (231, array([0.]))
# (232, array([0.]))
# (233, array([0.]))
# (234, array([0.]))
# (235, array([0.]))
# (236, array([0.]))
# (237, array([-1.]))
# (238, array([-1.]))
# (239, array([-1.]))
# (240, array([-1.]))
# (241, array([-1.]))
# (242, array([-1.]))
# (243, array([0.]))
# (244, array([0.]))
# (245, array([0.]))
# (246, array([0.]))
# (247, array([0.]))
# (248, array([0.]))
# (249, array([0.]))
# (250, array([0.]))
# (251, array([0.]))
# (252, array([0.]))
# (253, array([-1.]))
# (254, array([-1.]))
# (255, array([-1.]))
# (256, array([-1.]))
# (257, array([-1.]))
# (258, array([-1.]))
# (259, array([-1.]))
# (260, array([-1.]))
# (261, array([-1.]))
# (262, array([-1.]))
# (263, array([-1.]))
# (264, array([0.]))
# (265, array([0.]))
# (266, array([0.]))
# (267, array([0.]))
# (268, array([0.]))
# (269, array([0.]))
# (270, array([-1.]))
# (271, array([-1.]))
# (272, array([-1.]))
# (273, array([-1.]))
# (274, array([-1.]))
# (275, array([-1.]))
# (276, array([0.]))
# (277, array([0.]))
# (278, array([-1.]))
# (279, array([-1.]))
# (280, array([-1.]))
# (281, array([-1.]))
# (282, array([-1.]))
# (283, array([-1.]))
# (284, array([-1.]))
# (285, array([-1.]))
# (286, array([-1.]))
# (287, array([-1.]))
# (288, array([-1.]))
# (289, array([-1.]))
# (290, array([-1.]))
# (291, array([-1.]))
# (292, array([0.]))
# (293, array([0.]))
# (294, array([0.]))
# (295, array([0.]))
# (296, array([0.]))
# (297, array([0.]))
# (298, array([0.]))
# (299, array([0.]))
# (300, array([-1.]))
# (301, array([-1.]))
# (302, array([-1.]))
# (303, array([-1.]))
# (304, array([-1.]))
# (305, array([-1.]))
# (306, array([-1.]))
# (307, array([-1.]))
# (308, array([-1.]))
# (309, array([-1.]))
# (310, array([-1.]))
# (311, array([-1.]))
# (312, array([0.]))
# (313, array([0.]))
# (314, array([0.]))
# (315, array([0.]))
# (316, array([0.]))
# (317, array([-1.]))
# (318, array([-1.]))
# (319, array([-1.]))
# (320, array([-1.]))
# (321, array([-1.]))
# (322, array([-1.]))
# (323, array([-1.]))
# (324, array([-1.]))
# (325, array([-1.]))
# (326, array([0.]))
# (327, array([0.]))
# (328, array([0.]))
# (329, array([0.]))
# (330, array([0.]))
# (331, array([-1.]))
# (332, array([0.]))
# (333, array([-1.]))
# (334, array([-1.]))
# (335, array([-1.]))
# (336, array([-1.]))
# (337, array([-1.]))
# (338, array([-1.]))
# (339, array([0.]))
# (340, array([0.]))
# (341, array([0.]))
# (342, array([0.]))
# (343, array([0.]))
# (344, array([0.]))
# (345, array([0.]))
# (346, array([0.]))
# (347, array([0.]))
# (348, array([0.]))
# (349, array([-1.]))
# (350, array([-1.]))
# (351, array([-1.]))
# (352, array([-1.]))
# (353, array([-1.]))
# (354, array([-1.]))
# (355, array([-1.]))
# (356, array([-1.]))
# (357, array([-1.]))
# (358, array([0.]))
# (359, array([0.]))
# (360, array([0.]))
# (361, array([0.]))
# (362, array([0.]))
# (363, array([0.]))
# (364, array([0.]))
# (365, array([-1.]))
# (366, array([-1.]))
# (367, array([-1.]))
# (368, array([-1.]))
# (369, array([-1.]))
# (370, array([-1.]))
# (371, array([0.]))
# (372, array([0.]))
# (373, array([0.]))
# (374, array([0.]))
# (375, array([0.]))
# (376, array([0.]))
# (377, array([0.]))
# (378, array([0.]))
# (379, array([-1.]))
# (380, array([0.]))
# (381, array([0.]))
# (382, array([-1.]))
# (383, array([-1.]))
# (384, array([-1.]))
# (385, array([-1.]))
# (386, array([-1.]))
# (387, array([-1.]))
# (388, array([0.]))
# (389, array([0.]))
# (390, array([0.]))
# (391, array([0.]))
# (392, array([0.]))
# (393, array([0.]))
# (394, array([0.]))
# (395, array([0.]))
# (396, array([0.]))
# (397, array([0.]))
# (398, array([-1.]))
# (399, array([-1.]))
# (400, array([-1.]))
# (401, array([-1.]))
# (402, array([0.]))
# (403, array([0.]))
# (404, array([0.]))
# (405, array([0.]))
# (406, array([0.]))
# (407, array([0.]))
# (408, array([0.]))
# (409, array([0.]))
# (410, array([0.]))
# (411, array([0.]))
# (412, array([0.]))
# (413, array([0.]))
# (414, array([-1.]))
# (415, array([-1.]))
# (416, array([-1.]))
# (417, array([-1.]))
# (418, array([0.]))
# (419, array([0.]))
# (420, array([0.]))
# (421, array([0.]))
# (422, array([0.]))
# (423, array([0.]))
# (424, array([0.]))
# (425, array([0.]))
# (426, array([0.]))
# (427, array([0.]))
# (428, array([0.]))
# (429, array([0.]))
# (430, array([-1.]))
# (431, array([-1.]))
# (432, array([-1.]))
# (433, array([-1.]))
# (434, array([-1.]))
# (435, array([0.]))
# (436, array([0.]))
# (437, array([0.]))
# (438, array([0.]))
# (439, array([0.]))
# (440, array([0.]))
# (441, array([0.]))
# (442, array([0.]))
# (443, array([0.]))
# (444, array([0.]))
# (445, array([0.]))
# (446, array([-1.]))
# (447, array([-1.]))
# (448, array([-1.]))
# (449, array([-1.]))
# (450, array([-1.]))
# (451, array([-1.]))
# (452, array([-1.]))
# (453, array([-1.]))
# (454, array([-1.]))
# (455, array([-1.]))
# (456, array([-1.]))
# (457, array([0.]))
# (458, array([0.]))
# (459, array([0.]))
# (460, array([0.]))
# (461, array([-1.]))
# (462, array([-1.]))
# (463, array([-1.]))
# (464, array([-1.]))
# (465, array([-1.]))
# (466, array([-1.]))
# (467, array([-1.]))
# (468, array([-1.]))
# (469, array([-1.]))
# (470, array([-1.]))
# (471, array([-1.]))
# (472, array([-1.]))
# (473, array([0.]))
# (474, array([-1.]))
# (475, array([0.]))
# (476, array([-1.]))
# (477, array([-1.]))
# (478, array([-1.]))
# (479, array([-1.]))
# (480, array([-1.]))
# (481, array([-1.]))
# (482, array([-1.]))
# (483, array([0.]))
# (484, array([0.]))
# (485, array([0.]))
# (486, array([0.]))
# (487, array([0.]))
# (488, array([0.]))
# (489, array([0.]))
# (490, array([0.]))
# (491, array([0.]))
# (492, array([0.]))
# (493, array([0.]))
# (494, array([-1.]))
# (495, array([-1.]))
# (496, array([0.]))
# (497, array([0.]))
# (498, array([-1.]))
# (499, array([-1.]))
# (500, array([-1.]))
# (501, array([-1.]))
# (502, array([-1.]))
# (503, array([-1.]))
# (504, array([-1.]))
# (505, array([-1.]))
# (506, array([-1.]))
# (507, array([-1.]))
# (508, array([-1.]))
# (509, array([-1.]))
# (510, array([-1.]))
# (511, array([-1.]))
# (512, array([-1.]))
# (513, array([-1.]))
# (514, array([-1.]))
# (515, array([-1.]))
# (516, array([0.]))
# (517, array([0.]))
# (518, array([0.]))
# (519, array([0.]))
# (520, array([0.]))
# (521, array([0.]))
# (522, array([0.]))
# (523, array([0.]))
# (524, array([0.]))
# (525, array([-1.]))
# (526, array([-1.]))
# (527, array([-1.]))
# (528, array([-1.]))
# (529, array([-1.]))
# (530, array([-1.]))
# (531, array([0.]))
# (532, array([0.]))
# (533, array([0.]))
# (534, array([0.]))
# (535, array([0.]))
# (536, array([-1.]))
# (537, array([0.]))
# (538, array([0.]))
# (539, array([0.]))
# (540, array([0.]))
# (541, array([0.]))
# (542, array([-1.]))
# (543, array([-1.]))
# (544, array([-1.]))
# (545, array([-1.]))
# (546, array([-1.]))
# (547, array([-1.]))
# (548, array([0.]))
# (549, array([-1.]))
# (550, array([-1.]))
# (551, array([-1.]))
# (552, array([-1.]))
# (553, array([-1.]))
# (554, array([-1.]))
# (555, array([-1.]))
# (556, array([-1.]))
# (557, array([-1.]))
# (558, array([-1.]))
# (559, array([-1.]))
# (560, array([-1.]))
# (561, array([-1.]))
# (562, array([0.]))
# (563, array([0.]))
# (564, array([0.]))
# (565, array([0.]))
# (566, array([0.]))
# (567, array([0.]))
# (568, array([0.]))
# (569, array([0.]))
# (570, array([0.]))
# (571, array([0.]))
# (572, array([0.]))
# (573, array([0.]))
# (574, array([-1.]))
# (575, array([-1.]))
# (576, array([-1.]))
# (577, array([-1.]))
# (578, array([-1.]))
# (579, array([0.]))
# (580, array([0.]))
# (581, array([0.]))
# (582, array([0.]))
# (583, array([0.]))
# (584, array([0.]))
# (585, array([0.]))
# (586, array([0.]))
# (587, array([0.]))
# (588, array([0.]))
# (589, array([0.]))
# (590, array([-1.]))
# (591, array([-1.]))
# (592, array([-1.]))
# (593, array([-1.]))
# (594, array([0.]))
# (595, array([0.]))
# (596, array([0.]))
# (597, array([0.]))
# (598, array([0.]))
# (599, array([0.]))
# (600, array([0.]))
# (601, array([0.]))
# (602, array([0.]))
# (603, array([0.]))
# (604, array([0.]))
# (605, array([0.]))
# (606, array([-1.]))
# (607, array([-1.]))
# (608, array([-1.]))
# (609, array([-1.]))
# (610, array([-1.]))
# (611, array([-1.]))
# (612, array([-1.]))
# (613, array([0.]))
# (614, array([0.]))
# (615, array([0.]))
# (616, array([0.]))
# (617, array([0.]))
# (618, array([0.]))
# (619, array([0.]))
# (620, array([0.]))
# (621, array([0.]))
# (622, array([-1.]))
# (623, array([-1.]))
# (624, array([-1.]))
# (625, array([-1.]))
# (626, array([-1.]))
# (627, array([0.]))
# (628, array([-1.]))
# (629, array([-1.]))
# (630, array([-1.]))
# (631, array([-1.]))
# (632, array([-1.]))
# (633, array([-1.]))
# (634, array([-1.]))
# (635, array([-1.]))
# (636, array([-1.]))
# (637, array([0.]))
# (638, array([-1.]))
# (639, array([-1.]))
# (640, array([-1.]))
# (641, array([-1.]))
# (642, array([-1.]))
# (643, array([-1.]))
# (644, array([-1.]))
# (645, array([-1.]))
# (646, array([-1.]))
# (647, array([-1.]))
# (648, array([-1.]))
# (649, array([0.]))
# (650, array([0.]))
# (651, array([0.]))
# (652, array([0.]))
# (653, array([0.]))
# (654, array([-1.]))
# (655, array([-1.]))
# (656, array([-1.]))
# (657, array([-1.]))
# (658, array([-1.]))
# (659, array([-1.]))
# (660, array([0.]))
# (661, array([0.]))
# (662, array([0.]))
# (663, array([0.]))
# (664, array([0.]))
# (665, array([0.]))
# (666, array([0.]))
# (667, array([0.]))
# (668, array([0.]))
# (669, array([0.]))
# (670, array([-1.]))
# (671, array([-1.]))
# (672, array([-1.]))
# (673, array([-1.]))
# (674, array([-1.]))
# (675, array([-1.]))
# (676, array([0.]))
# (677, array([0.]))
# (678, array([0.]))
# (679, array([0.]))
# (680, array([0.]))
# (681, array([0.]))
# (682, array([0.]))
# (683, array([0.]))
# (684, array([0.]))
# (685, array([0.]))
# (686, array([-1.]))
# (687, array([-1.]))
# (688, array([-1.]))
# (689, array([-1.]))
# (690, array([0.]))
# (691, array([0.]))
# (692, array([-1.]))
# (693, array([-1.]))
# (694, array([-1.]))
# (695, array([-1.]))
# (696, array([0.]))
# (697, array([0.]))
# (698, array([0.]))
# (699, array([0.]))
# (700, array([0.]))
# (701, array([0.]))
# (702, array([-1.]))
# (703, array([-1.]))
# (704, array([-1.]))
# (705, array([-1.]))
# (706, array([-1.]))
# (707, array([-1.]))
# (708, array([-1.]))
# (709, array([-1.]))
# (710, array([-1.]))
# (711, array([-1.]))
# (712, array([0.]))
# (713, array([0.]))
# (714, array([0.]))
# (715, array([0.]))
# (716, array([0.]))
# (717, array([0.]))
# (718, array([-1.]))
# (719, array([-1.]))
# (720, array([0.]))
# (721, array([-1.]))
# (722, array([-1.]))
# (723, array([-1.]))
# (724, array([-1.]))
# (725, array([-1.]))
# (726, array([-1.]))
# (727, array([-1.]))
# (728, array([0.]))
# (729, array([0.]))
# (730, array([0.]))
# (731, array([0.]))
# (732, array([0.]))
# (733, array([0.]))
# (734, array([-1.]))
# (735, array([-1.]))
# (736, array([-1.]))
# (737, array([-1.]))
# (738, array([-1.]))
# (739, array([-1.]))
# (740, array([-1.]))
# (741, array([0.]))
# (742, array([-1.]))
# (743, array([0.]))
# (744, array([-1.]))
# (745, array([-1.]))
# (746, array([-1.]))
# (747, array([-1.]))
# (748, array([0.]))
# (749, array([-1.]))
# (750, array([-1.]))
# (751, array([-1.]))
# (752, array([-1.]))
# (753, array([-1.]))
# (754, array([-1.]))
# (755, array([0.]))
# (756, array([0.]))
# (757, array([0.]))
# (758, array([0.]))
# (759, array([0.]))
# (760, array([0.]))
# (761, array([0.]))
# (762, array([0.]))
# (763, array([0.]))
# (764, array([0.]))
# (765, array([0.]))
# (766, array([-1.]))
# (767, array([-1.]))
# (768, array([-1.]))
# (769, array([-1.]))
# (770, array([-1.]))
# (771, array([-1.]))
# (772, array([-1.]))
# (773, array([-1.]))
# (774, array([-1.]))
# (775, array([0.]))
# (776, array([0.]))
# (777, array([0.]))
# (778, array([0.]))
# (779, array([0.]))
# (780, array([0.]))
# (781, array([0.]))
# (782, array([-1.]))
# (783, array([-1.]))
# (784, array([-1.]))
# (785, array([-1.]))
# (786, array([-1.]))
# (787, array([-1.]))
# (788, array([0.]))
# (789, array([0.]))
# (790, array([-1.]))
# (791, array([0.]))
# (792, array([0.]))
# (793, array([0.]))
# (794, array([0.]))
# (795, array([0.]))
# (796, array([0.]))
# (797, array([-1.]))
# (798, array([-1.]))
# (799, array([-1.]))
# (800, array([-1.]))
# (801, array([-1.]))
# (802, array([0.]))
# (803, array([0.]))
# (804, array([0.]))
# (805, array([0.]))
# (806, array([0.]))
# (807, array([0.]))
# (808, array([0.]))
# (809, array([0.]))
# (810, array([0.]))
# (811, array([0.]))
# (812, array([0.]))
# (813, array([0.]))
# (814, array([-1.]))
# (815, array([-1.]))
# (816, array([-1.]))
# (817, array([-1.]))
# (818, array([-1.]))
# (819, array([-1.]))
# (820, array([-1.]))
# (821, array([0.]))
# (822, array([-1.]))
# (823, array([0.]))
# (824, array([0.]))
# (825, array([0.]))
# (826, array([0.]))
# (827, array([0.]))
# (828, array([0.]))
# (829, array([0.]))
# (830, array([-1.]))
# (831, array([-1.]))
# (832, array([0.]))
# (833, array([0.]))
# (834, array([0.]))
# (835, array([0.]))
# (836, array([0.]))
# (837, array([0.]))
# (838, array([0.]))
# (839, array([0.]))
# (840, array([0.]))
# (841, array([0.]))
# (842, array([0.]))
# (843, array([0.]))
# (844, array([0.]))
# (845, array([0.]))
# (846, array([-1.]))
# (847, array([-1.]))
# (848, array([0.]))
# (849, array([0.]))
# (850, array([0.]))
# (851, array([0.]))
# (852, array([0.]))
# (853, array([0.]))
# (854, array([0.]))
# (855, array([0.]))
# (856, array([0.]))
# (857, array([0.]))
# (858, array([0.]))
# (859, array([0.]))
# (860, array([0.]))
# (861, array([0.]))
# (862, array([-1.]))
# (863, array([-1.]))
# (864, array([-1.]))
# (865, array([0.]))
# (866, array([0.]))
# (867, array([0.]))
# (868, array([0.]))
# (869, array([0.]))
# (870, array([0.]))
# (871, array([0.]))
# (872, array([0.]))
# (873, array([0.]))
# (874, array([0.]))
# (875, array([0.]))
# (876, array([0.]))
# (877, array([0.]))
# (878, array([-1.]))
# (879, array([-1.]))
# (880, array([-1.]))
# (881, array([0.]))
# (882, array([0.]))
# (883, array([0.]))
# (884, array([0.]))
# (885, array([0.]))
# (886, array([0.]))
# (887, array([0.]))
# (888, array([0.]))
# (889, array([0.]))
# (890, array([0.]))
# (891, array([0.]))
# (892, array([0.]))
# (893, array([0.]))
# (894, array([-1.]))
# (895, array([-1.]))
# (896, array([-1.]))
# (897, array([0.]))
# (898, array([0.]))
# (899, array([0.]))
# (900, array([0.]))
# (901, array([0.]))
# (902, array([0.]))
# (903, array([0.]))
# (904, array([0.]))
# (905, array([0.]))
# (906, array([0.]))
# (907, array([0.]))
# (908, array([0.]))
# (909, array([0.]))
# (910, array([-1.]))
# (911, array([-1.]))
# (912, array([-1.]))
# (913, array([0.]))
# (914, array([0.]))
# (915, array([0.]))
# (916, array([0.]))
# (917, array([0.]))
# (918, array([0.]))
# (919, array([0.]))
# (920, array([0.]))
# (921, array([0.]))
# (922, array([0.]))
# (923, array([0.]))
# (924, array([0.]))
# (925, array([0.]))
# (926, array([-1.]))
# (927, array([-1.]))
# (928, array([-1.]))
# (929, array([-1.]))
# (930, array([-1.]))
# (931, array([0.]))
# (932, array([0.]))
# (933, array([0.]))
# (934, array([0.]))
# (935, array([0.]))
# (936, array([0.]))
# (937, array([0.]))
# (938, array([0.]))
# (939, array([0.]))
# (940, array([0.]))
# (941, array([0.]))
# (942, array([-1.]))
# (943, array([-1.]))
# (944, array([0.]))
# (945, array([0.]))
# (946, array([0.]))
# (947, array([0.]))
# (948, array([0.]))
# (949, array([0.]))
# (950, array([0.]))
# (951, array([0.]))
# (952, array([0.]))
# (953, array([0.]))
# (954, array([0.]))
# (955, array([0.]))
# (956, array([0.]))
# (957, array([0.]))
# (958, array([-1.]))
# (959, array([-1.]))
# (960, array([-1.]))
# (961, array([-1.]))
# (962, array([0.]))
# (963, array([0.]))
# (964, array([0.]))
# (965, array([0.]))
# (966, array([0.]))
# (967, array([0.]))
# (968, array([0.]))
# (969, array([0.]))
# (970, array([0.]))
# (971, array([0.]))
# (972, array([0.]))
# (973, array([0.]))
# (974, array([-1.]))
# (975, array([-1.]))
# (976, array([-1.]))
# (977, array([-1.]))
# (978, array([-1.]))
# (979, array([-1.]))
# (980, array([-1.]))
# (981, array([-1.]))
# (982, array([0.]))
# (983, array([0.]))
# (984, array([0.]))
# (985, array([0.]))
# (986, array([0.]))
# (987, array([0.]))
# (988, array([0.]))
# (989, array([0.]))
# (990, array([-1.]))
# (991, array([-1.]))
# (992, array([-1.]))
# (993, array([0.]))
# (994, array([-1.]))
# (995, array([-1.]))
# (996, array([0.]))
# (997, array([0.]))
# (998, array([0.]))
# (999, array([0.]))
# (1000, array([0.]))
# (1001, array([0.]))
# (1002, array([0.]))
# (1003, array([0.]))
# (1004, array([0.]))
# (1005, array([0.]))
# (1006, array([-1.]))
# (1007, array([-1.]))
# (1008, array([-1.]))
# (1009, array([-1.]))
# (1010, array([-1.]))
# (1011, array([-1.]))
# (1012, array([-1.]))
# (1013, array([0.]))
# (1014, array([0.]))
# (1015, array([0.]))
# (1016, array([0.]))
# (1017, array([0.]))
# (1018, array([0.]))
# (1019, array([0.]))
# (1020, array([0.]))
# (1021, array([0.]))
# (1022, array([-1.]))
# (1023, array([-1.]))
# (1024, array([-1.]))
# (1025, array([0.]))
# (1026, array([0.]))
# (1027, array([0.]))
# (1028, array([0.]))
# (1029, array([0.]))
# (1030, array([0.]))
# (1031, array([0.]))
# (1032, array([0.]))
# (1033, array([0.]))
# (1034, array([0.]))
# (1035, array([0.]))
# (1036, array([0.]))
# (1037, array([0.]))
# (1038, array([-1.]))
# (1039, array([-1.]))
# (1040, array([-1.]))
# (1041, array([-1.]))
# (1042, array([-1.]))
# (1043, array([-1.]))
# (1044, array([-1.]))
# (1045, array([-1.]))
# (1046, array([-1.]))
# (1047, array([-1.]))
# (1048, array([0.]))
# (1049, array([0.]))
# (1050, array([0.]))
# (1051, array([0.]))
# (1052, array([0.]))
# (1053, array([0.]))
# (1054, array([-1.]))
# (1055, array([-1.]))
# (1056, array([-1.]))
# (1057, array([-1.]))
# (1058, array([-1.]))
# (1059, array([-1.]))
# (1060, array([-1.]))
# (1061, array([-1.]))
# (1062, array([-1.]))
# (1063, array([-1.]))
# (1064, array([-1.]))
# (1065, array([0.]))
# (1066, array([0.]))
# (1067, array([0.]))
# (1068, array([0.]))
# (1069, array([0.]))
# (1070, array([-1.]))
# (1071, array([-1.]))
# (1072, array([-1.]))
# (1073, array([-1.]))
# (1074, array([-1.]))
# (1075, array([-1.]))
# (1076, array([-1.]))
# (1077, array([-1.]))
# (1078, array([-1.]))
# (1079, array([-1.]))
# (1080, array([-1.]))
# (1081, array([0.]))
# (1082, array([0.]))
# (1083, array([0.]))
# (1084, array([0.]))
# (1085, array([0.]))
# (1086, array([-1.]))
# (1087, array([-1.]))
# (1088, array([-1.]))
# (1089, array([-1.]))
# (1090, array([-1.]))
# (1091, array([-1.]))
# (1092, array([-1.]))
# (1093, array([-1.]))
# (1094, array([-1.]))
# (1095, array([-1.]))
# (1096, array([0.]))
# (1097, array([0.]))
# (1098, array([0.]))
# (1099, array([0.]))
# (1100, array([0.]))
# (1101, array([0.]))
# (1102, array([-1.]))
# (1103, array([-1.]))
# (1104, array([-1.]))
# (1105, array([-1.]))
# (1106, array([-1.]))
# (1107, array([-1.]))
# (1108, array([-1.]))
# (1109, array([0.]))
# (1110, array([0.]))
# (1111, array([0.]))
# (1112, array([0.]))
# (1113, array([0.]))
# (1114, array([0.]))
# (1115, array([0.]))
# (1116, array([0.]))
# (1117, array([0.]))
# (1118, array([-1.]))
# (1119, array([-1.]))
# (1120, array([-1.]))
# (1121, array([-1.]))
# (1122, array([-1.]))
# (1123, array([-1.]))
# (1124, array([-1.]))
# (1125, array([0.]))
# (1126, array([0.]))
# (1127, array([0.]))
# (1128, array([0.]))
# (1129, array([0.]))
# (1130, array([0.]))
# (1131, array([0.]))
# (1132, array([0.]))
# (1133, array([0.]))
# (1134, array([-1.]))
# (1135, array([-1.]))
# (1136, array([-1.]))
# (1137, array([-1.]))
# (1138, array([-1.]))
# (1139, array([-1.]))
# (1140, array([-1.]))
# (1141, array([-1.]))
# (1142, array([-1.]))
# (1143, array([-1.]))
# (1144, array([-1.]))
# (1145, array([0.]))
# (1146, array([0.]))
# (1147, array([0.]))
# (1148, array([0.]))
# (1149, array([0.]))
# (1150, array([-1.]))
# (1151, array([-1.]))
# (1152, array([-1.]))
# (1153, array([-1.]))
# (1154, array([-1.]))
# (1155, array([-1.]))
# (1156, array([-1.]))
# (1157, array([0.]))
# (1158, array([0.]))
# (1159, array([0.]))
# (1160, array([0.]))
# (1161, array([0.]))
# (1162, array([0.]))
# (1163, array([0.]))
# (1164, array([0.]))
# (1165, array([0.]))
# (1166, array([-1.]))
# (1167, array([-1.]))
# (1168, array([0.]))
# (1169, array([0.]))
# (1170, array([-1.]))
# (1171, array([0.]))
# (1172, array([-1.]))
# (1173, array([-1.]))
# (1174, array([-1.]))
# (1175, array([-1.]))
# (1176, array([-1.]))
# (1177, array([0.]))
# (1178, array([0.]))
# (1179, array([0.]))
# (1180, array([0.]))
# (1181, array([0.]))
# (1182, array([-1.]))
# (1183, array([-1.]))
# (1184, array([-1.]))
# (1185, array([-1.]))
# (1186, array([-1.]))
# (1187, array([0.]))
# (1188, array([0.]))
# (1189, array([0.]))
# (1190, array([0.]))
# (1191, array([0.]))
# (1192, array([0.]))
# (1193, array([0.]))
# (1194, array([0.]))
# (1195, array([0.]))
# (1196, array([0.]))
# (1197, array([0.]))
# (1198, array([-1.]))
# (1199, array([-1.]))
# (1200, array([-1.]))
# (1201, array([-1.]))
# (1202, array([-1.]))
# (1203, array([-1.]))
# (1204, array([-1.]))
# (1205, array([-1.]))
# (1206, array([-1.]))
# (1207, array([-1.]))
# (1208, array([0.]))
# (1209, array([0.]))
# (1210, array([0.]))
# (1211, array([0.]))
# (1212, array([0.]))
# (1213, array([0.]))
# (1214, array([-1.]))
# (1215, array([-1.]))
# (1216, array([-1.]))
# (1217, array([-1.]))
# (1218, array([-1.]))
# (1219, array([0.]))
# (1220, array([0.]))
# (1221, array([0.]))
# (1222, array([0.]))
# (1223, array([0.]))
# (1224, array([0.]))
# (1225, array([0.]))
# (1226, array([0.]))
# (1227, array([0.]))
# (1228, array([0.]))
# (1229, array([0.]))
# (1230, array([-1.]))
# (1231, array([-1.]))
# (1232, array([-1.]))
# (1233, array([-1.]))
# (1234, array([-1.]))
# (1235, array([0.]))
# (1236, array([0.]))
# (1237, array([0.]))
# (1238, array([0.]))
# (1239, array([0.]))
# (1240, array([0.]))
# (1241, array([0.]))
# (1242, array([0.]))
# (1243, array([0.]))
# (1244, array([0.]))
# (1245, array([0.]))
# (1246, array([-1.]))
# (1247, array([-1.]))
# (1248, array([-1.]))
# (1249, array([-1.]))
# (1250, array([-1.]))
# (1251, array([-1.]))
# (1252, array([0.]))
# (1253, array([0.]))
# (1254, array([0.]))
# (1255, array([0.]))
# (1256, array([0.]))
# (1257, array([0.]))
# (1258, array([0.]))
# (1259, array([0.]))
# (1260, array([0.]))
# (1261, array([0.]))
# (1262, array([-1.]))
# (1263, array([-1.]))
# (1264, array([-1.]))
# (1265, array([-1.]))
# (1266, array([-1.]))
# (1267, array([-1.]))
# (1268, array([0.]))
# (1269, array([0.]))
# (1270, array([0.]))
# (1271, array([0.]))
# (1272, array([0.]))
# (1273, array([0.]))
# (1274, array([0.]))
# (1275, array([0.]))
# (1276, array([0.]))
# (1277, array([0.]))
# (1278, array([-1.]))
# (1279, array([-1.]))
# (1280, array([-1.]))
# (1281, array([-1.]))
# (1282, array([-1.]))
# (1283, array([-1.]))
# (1284, array([0.]))
# (1285, array([0.]))
# (1286, array([0.]))
# (1287, array([0.]))
# (1288, array([0.]))
# (1289, array([0.]))
# (1290, array([0.]))
# (1291, array([0.]))
# (1292, array([0.]))
# (1293, array([0.]))
# (1294, array([-1.]))
# (1295, array([-1.]))
# (1296, array([-1.]))
# (1297, array([-1.]))
# (1298, array([-1.]))
# (1299, array([-1.]))
# (1300, array([0.]))
# (1301, array([0.]))
# (1302, array([0.]))
# (1303, array([0.]))
# (1304, array([0.]))
# (1305, array([0.]))
# (1306, array([0.]))
# (1307, array([0.]))
# (1308, array([0.]))
# (1309, array([0.]))
# (1310, array([-1.]))
# (1311, array([-1.]))
# (1312, array([-1.]))
# (1313, array([-1.]))
# (1314, array([0.]))
# (1315, array([0.]))
# (1316, array([0.]))
# (1317, array([0.]))
# (1318, array([0.]))
# (1319, array([0.]))
# (1320, array([0.]))
# (1321, array([0.]))
# (1322, array([0.]))
# (1323, array([0.]))
# (1324, array([0.]))
# (1325, array([0.]))
# (1326, array([-1.]))
# (1327, array([-1.]))
# (1328, array([-1.]))
# (1329, array([-1.]))
# (1330, array([-1.]))
# (1331, array([0.]))
# (1332, array([0.]))
# (1333, array([0.]))
# (1334, array([0.]))
# (1335, array([0.]))
# (1336, array([0.]))
# (1337, array([0.]))
# (1338, array([0.]))
# (1339, array([0.]))
# (1340, array([0.]))
# (1341, array([0.]))
# (1342, array([-1.]))
# (1343, array([-1.]))
# (1344, array([-1.]))
# (1345, array([-1.]))
# (1346, array([-1.]))
# (1347, array([-1.]))
# (1348, array([-1.]))
# (1349, array([-1.]))
# (1350, array([0.]))
# (1351, array([0.]))
# (1352, array([0.]))
# (1353, array([0.]))
# (1354, array([0.]))
# (1355, array([0.]))
# (1356, array([0.]))
# (1357, array([0.]))
# (1358, array([-1.]))
# (1359, array([-1.]))
# (1360, array([-1.]))
# (1361, array([-1.]))
# (1362, array([-1.]))
# (1363, array([0.]))
# (1364, array([0.]))
# (1365, array([0.]))
# (1366, array([0.]))
# (1367, array([0.]))
# (1368, array([0.]))
# (1369, array([0.]))
# (1370, array([0.]))
# (1371, array([0.]))
# (1372, array([0.]))
# (1373, array([0.]))
# (1374, array([-1.]))
# (1375, array([-1.]))
# (1376, array([-1.]))
# (1377, array([-1.]))
# (1378, array([-1.]))
# (1379, array([-1.]))
# (1380, array([-1.]))
# (1381, array([-1.]))
# (1382, array([-1.]))
# (1383, array([0.]))
# (1384, array([0.]))
# (1385, array([0.]))
# (1386, array([0.]))
# (1387, array([0.]))
# (1388, array([0.]))
# (1389, array([0.]))
# (1390, array([-1.]))
# (1391, array([-1.]))
# (1392, array([0.]))
# (1393, array([0.]))
# (1394, array([-1.]))
# (1395, array([-1.]))
# (1396, array([-1.]))
# (1397, array([-1.]))
# (1398, array([-1.]))
# (1399, array([-1.]))
# (1400, array([-1.]))
# (1401, array([-1.]))
# (1402, array([-1.]))
# (1403, array([-1.]))
# (1404, array([0.]))
# (1405, array([0.]))
# (1406, array([-1.]))
# (1407, array([-1.]))
# (1408, array([-1.]))
# (1409, array([-1.]))
# (1410, array([-1.]))
# (1411, array([-1.]))
# (1412, array([-1.]))
# (1413, array([-1.]))
# (1414, array([0.]))
# (1415, array([0.]))
# (1416, array([0.]))
# (1417, array([0.]))
# (1418, array([0.]))
# (1419, array([0.]))
# (1420, array([0.]))
# (1421, array([0.]))
# (1422, array([-1.]))
# (1423, array([-1.]))
# (1424, array([-1.]))
# (1425, array([-1.]))
# (1426, array([-1.]))
# (1427, array([0.]))
# (1428, array([0.]))
# (1429, array([0.]))
# (1430, array([0.]))
# (1431, array([0.]))
# (1432, array([0.]))
# (1433, array([0.]))
# (1434, array([0.]))
# (1435, array([0.]))
# (1436, array([0.]))
# (1437, array([0.]))
# (1438, array([-1.]))
# (1439, array([-1.]))
# (1440, array([-1.]))
# (1441, array([-1.]))
# (1442, array([-1.]))
# (1443, array([-1.]))
# (1444, array([-1.]))
# (1445, array([-1.]))
# (1446, array([-1.]))
# (1447, array([-1.]))
# (1448, array([-1.]))
# (1449, array([0.]))
# (1450, array([0.]))
# (1451, array([0.]))
# (1452, array([0.]))
# (1453, array([0.]))
# (1454, array([-1.]))
# (1455, array([-1.]))
# (1456, array([-1.]))
# (1457, array([-1.]))
# (1458, array([0.]))
# (1459, array([0.]))
# (1460, array([0.]))
# (1461, array([0.]))
# (1462, array([0.]))
# (1463, array([0.]))
# (1464, array([0.]))
# (1465, array([0.]))
# (1466, array([0.]))
# (1467, array([0.]))
# (1468, array([0.]))
# (1469, array([0.]))
# (1470, array([-1.]))
# (1471, array([-1.]))
# (1472, array([-1.]))
# (1473, array([-1.]))
# (1474, array([-1.]))
# (1475, array([-1.]))
# (1476, array([-1.]))
# (1477, array([-1.]))
# (1478, array([-1.]))
# (1479, array([-1.]))
# (1480, array([0.]))
# (1481, array([0.]))
# (1482, array([0.]))
# (1483, array([0.]))
# (1484, array([0.]))
# (1485, array([0.]))
# (1486, array([-1.]))
# (1487, array([-1.]))
# (1488, array([0.]))
# (1489, array([0.]))
# (1490, array([0.]))
# (1491, array([0.]))
# (1492, array([0.]))
# (1493, array([0.]))
# (1494, array([0.]))
# (1495, array([0.]))
# (1496, array([0.]))
# (1497, array([0.]))
# (1498, array([0.]))
# (1499, array([0.]))
# (1500, array([0.]))
# (1501, array([0.]))
# (1502, array([-1.]))
# (1503, array([-1.]))
# (1504, array([0.]))
# (1505, array([0.]))
# (1506, array([-1.]))
# (1507, array([0.]))
# (1508, array([-1.]))
# (1509, array([-1.]))
# (1510, array([-1.]))
# (1511, array([-1.]))
# (1512, array([-1.]))
# (1513, array([-1.]))
# (1514, array([0.]))
# (1515, array([0.]))
# (1516, array([-1.]))
# (1517, array([-1.]))
# (1518, array([-1.]))
# (1519, array([-1.]))
# (1520, array([0.]))
# (1521, array([0.]))
# (1522, array([0.]))
# (1523, array([0.]))
# (1524, array([-1.]))
# (1525, array([-1.]))
# (1526, array([-1.]))
# (1527, array([-1.]))
# (1528, array([-1.]))
# (1529, array([0.]))
# (1530, array([0.]))
# (1531, array([-1.]))
# (1532, array([0.]))
# (1533, array([0.]))
# (1534, array([-1.]))
# (1535, array([-1.]))
# (1536, array([-1.]))
# (1537, array([-1.]))
# (1538, array([-1.]))
# (1539, array([-1.]))
# (1540, array([-1.]))
# (1541, array([-1.]))
# (1542, array([-1.]))
# (1543, array([-1.]))
# (1544, array([-1.]))
# (1545, array([0.]))
# (1546, array([0.]))
# (1547, array([0.]))
# (1548, array([0.]))
# (1549, array([-1.]))
# (1550, array([-1.]))
# (1551, array([-1.]))
# (1552, array([-1.]))
# (1553, array([-1.]))
# (1554, array([-1.]))
# (1555, array([0.]))
# (1556, array([0.]))
# (1557, array([0.]))
# (1558, array([0.]))
# (1559, array([0.]))
# (1560, array([0.]))
# (1561, array([0.]))
# (1562, array([0.]))
# (1563, array([0.]))
# (1564, array([0.]))
# (1565, array([0.]))
# (1566, array([-1.]))
# (1567, array([-1.]))
# (1568, array([-1.]))
# (1569, array([0.]))
# (1570, array([-1.]))
# (1571, array([0.]))
# (1572, array([-1.]))
# (1573, array([0.]))
# (1574, array([-1.]))
# (1575, array([0.]))
# (1576, array([0.]))
# (1577, array([0.]))
# (1578, array([0.]))
# (1579, array([0.]))
# (1580, array([0.]))
# (1581, array([-1.]))
# (1582, array([-1.]))
# (1583, array([-1.]))
# (1584, array([-1.]))
# (1585, array([-1.]))
# (1586, array([-1.]))
# (1587, array([-1.]))
# (1588, array([-1.]))
# (1589, array([-1.]))
# (1590, array([-1.]))
# (1591, array([-1.]))
# (1592, array([-1.]))
# (1593, array([0.]))
# (1594, array([0.]))
# (1595, array([0.]))
# (1596, array([0.]))
# (1597, array([0.]))
# (1598, array([-1.]))
# (1599, array([-1.]))
# (1600, array([-1.]))
# (1601, array([-1.]))
# (1602, array([-1.]))
# (1603, array([-1.]))
# (1604, array([-1.]))
# (1605, array([-1.]))
# (1606, array([-1.]))
# (1607, array([-1.]))
# (1608, array([-1.]))
# (1609, array([0.]))
# (1610, array([0.]))
# (1611, array([0.]))
# (1612, array([0.]))
# (1613, array([0.]))
# (1614, array([-1.]))
# (1615, array([-1.]))
# (1616, array([-1.]))
# (1617, array([-1.]))
# (1618, array([-1.]))
# (1619, array([-1.]))
# (1620, array([-1.]))
# (1621, array([-1.]))
# (1622, array([-1.]))
# (1623, array([-1.]))
# (1624, array([0.]))
# (1625, array([0.]))
# (1626, array([0.]))
# (1627, array([0.]))
# (1628, array([0.]))
# (1629, array([0.]))
# (1630, array([-1.]))
# (1631, array([-1.]))
# (1632, array([-1.]))
# (1633, array([0.]))
# (1634, array([0.]))
# (1635, array([0.]))
# (1636, array([0.]))
# (1637, array([0.]))
# (1638, array([0.]))
# (1639, array([0.]))
# (1640, array([0.]))
# (1641, array([0.]))
# (1642, array([0.]))
# (1643, array([0.]))
# (1644, array([0.]))
# (1645, array([0.]))
# (1646, array([-1.]))
# (1647, array([-1.]))
# (1648, array([-1.]))
# (1649, array([0.]))
# (1650, array([0.]))
# (1651, array([0.]))
# (1652, array([0.]))
# (1653, array([0.]))
# (1654, array([0.]))
# (1655, array([0.]))
# (1656, array([0.]))
# (1657, array([0.]))
# (1658, array([0.]))
# (1659, array([0.]))
# (1660, array([0.]))
# (1661, array([0.]))
# (1662, array([-1.]))
# (1663, array([-1.]))
# (1664, array([-1.]))
# (1665, array([0.]))
# (1666, array([0.]))
# (1667, array([0.]))
# (1668, array([0.]))
# (1669, array([0.]))
# (1670, array([0.]))
# (1671, array([0.]))
# (1672, array([0.]))
# (1673, array([0.]))
# (1674, array([0.]))
# (1675, array([0.]))
# (1676, array([0.]))
# (1677, array([0.]))
# (1678, array([-1.]))
# (1679, array([-1.]))

# %%
for number in enumerate(import_price_value):
    print(number)
# Out:
# (0, 15.6555)
# (1, 14.8155)
# (2, 14.511)
# (3, 13.5345)
# (4, 13.8075)
# (5, 12.789000000000001)
# (6, 13.251)
# (7, 12.6525)
# (8, 14.112)
# (9, 13.23)
# (10, 13.23)
# (11, 12.789000000000001)
# (12, 12.243)
# (13, 13.671)
# (14, 24.6855)
# (15, 27.594)
# (16, 15.7185)
# (17, 15.435)
# (18, 16.0125)
# (19, 15.435)
# (20, 16.1385)
# (21, 15.96)
# (22, 15.876)
# (23, 15.2145)
# (24, 14.7735)
# (25, 13.8285)
# (26, 13.8495)
# (27, 13.0305)
# (28, 12.347999999999999)
# (29, 13.692)
# (30, 24.948)
# (31, 27.258000000000003)
# (32, 12.5685)
# (33, 13.23)
# (34, 13.9335)
# (35, 12.012)
# (36, 12.1275)
# (37, 11.445)
# (38, 11.6025)
# (39, 11.445)
# (40, 11.6865)
# (41, 11.445)
# (42, 11.3085)
# (43, 10.2795)
# (44, 10.227)
# (45, 10.227)
# (46, 23.625)
# (47, 27.594)
# (48, 10.5105)
# (49, 10.92)
# (50, 11.6865)
# (51, 11.466)
# (52, 11.466)
# (53, 11.360999999999999)
# (54, 11.466)
# (55, 11.907)
# (56, 12.327)
# (57, 12.1275)
# (58, 12.347999999999999)
# (59, 11.844000000000001)
# (60, 10.0065)
# (61, 10.647)
# (62, 24.3075)
# (63, 28.035)
# (64, 13.145999999999999)
# (65, 13.9335)
# (66, 13.9335)
# (67, 12.285)
# (68, 12.789000000000001)
# (69, 12.1275)
# (70, 12.1275)
# (71, 11.7495)
# (72, 12.1275)
# (73, 11.823)
# (74, 12.1275)
# (75, 12.1695)
# (76, 11.424000000000001)
# (77, 13.0095)
# (78, 24.15)
# (79, 26.796)
# (80, 14.112)
# (81, 13.0935)
# (82, 13.0305)
# (83, 11.2455)
# (84, 11.6235)
# (85, 11.025)
# (86, 11.2245)
# (87, 11.025)
# (88, 11.802)
# (89, 11.025)
# (90, 11.6235)
# (91, 11.025)
# (92, 11.2665)
# (93, 13.23)
# (94, 23.625)
# (95, 26.712)
# (96, 12.725999999999999)
# (97, 11.508)
# (98, 12.0645)
# (99, 10.8045)
# (100, 10.940999999999999)
# (101, 10.185)
# (102, 10.185)
# (103, 10.185)
# (104, 10.647)
# (105, 10.185)
# (106, 10.689)
# (107, 10.626)
# (108, 10.520999999999999)
# (109, 11.907)
# (110, 23.625)
# (111, 27.153000000000002)
# (112, 13.671)
# (113, 12.5685)
# (114, 11.907)
# (115, 11.6865)
# (116, 10.584000000000001)
# (117, 10.3005)
# (118, 9.9225)
# (119, 9.9225)
# (120, 10.142999999999999)
# (121, 9.9225)
# (122, 10.3005)
# (123, 10.142999999999999)
# (124, 10.2795)
# (125, 10.2795)
# (126, 23.0475)
# (127, 25.83)
# (128, 12.1275)
# (129, 12.1275)
# (130, 13.4505)
# (131, 13.0095)
# (132, 12.9675)
# (133, 12.831)
# (134, 12.1485)
# (135, 11.025)
# (136, 10.940999999999999)
# (137, 10.3635)
# (138, 10.626)
# (139, 10.059)
# (140, 9.9645)
# (141, 10.8885)
# (142, 22.9845)
# (143, 25.389)
# (144, 11.466)
# (145, 11.466)
# (146, 11.025)
# (147, 10.4055)
# (148, 10.7835)
# (149, 10.479000000000001)
# (150, 10.584000000000001)
# (151, 10.142999999999999)
# (152, 10.562999999999999)
# (153, 10.164)
# (154, 10.584000000000001)
# (155, 9.702)
# (156, 9.5235)
# (157, 9.24)
# (158, 22.5225)
# (159, 24.2235)
# (160, 13.23)
# (161, 13.9755)
# (162, 14.994000000000002)
# (163, 14.552999999999999)
# (164, 13.5135)
# (165, 13.251)
# (166, 12.789000000000001)
# (167, 12.5265)
# (168, 9.8805)
# (169, 9.66)
# (170, 9.681000000000001)
# (171, 9.66)
# (172, 9.5655)
# (173, 9.8805)
# (174, 22.6065)
# (175, 25.83)
# (176, 14.552999999999999)
# (177, 13.23)
# (178, 13.4505)
# (179, 12.347999999999999)
# (180, 11.6865)
# (181, 11.2455)
# (182, 11.907)
# (183, 11.2875)
# (184, 11.6655)
# (185, 11.466)
# (186, 11.025)
# (187, 11.382)
# (188, 10.08)
# (189, 13.145999999999999)
# (190, 24.7275)
# (191, 28.916999999999998)
# (192, 12.012)
# (193, 11.402999999999999)
# (194, 12.012)
# (195, 10.8045)
# (196, 10.142999999999999)
# (197, 9.8385)
# (198, 9.8805)
# (199, 9.5445)
# (200, 9.9645)
# (201, 9.9645)
# (202, 10.0065)
# (203, 10.0065)
# (204, 9.9855)
# (205, 11.466)
# (206, 22.323)
# (207, 25.389)
# (208, 13.0095)
# (209, 11.466)
# (210, 11.508)
# (211, 9.8805)
# (212, 9.9015)
# (213, 9.4605)
# (214, 9.3975)
# (215, 9.3975)
# (216, 9.261000000000001)
# (217, 9.261000000000001)
# (218, 9.3975)
# (219, 9.3975)
# (220, 9.4395)
# (221, 9.786)
# (222, 22.9635)
# (223, 25.011)
# (224, 13.0305)
# (225, 10.164)
# (226, 11.004000000000001)
# (227, 10.142999999999999)
# (228, 10.164)
# (229, 9.4185)
# (230, 9.24)
# (231, 9.219)
# (232, 9.219)
# (233, 9.219)
# (234, 9.261000000000001)
# (235, 9.24)
# (236, 9.4185)
# (237, 10.3215)
# (238, 22.1235)
# (239, 25.1685)
# (240, 13.314)
# (241, 11.466)
# (242, 11.025)
# (243, 9.4605)
# (244, 9.261000000000001)
# (245, 9.156)
# (246, 8.925)
# (247, 8.925)
# (248, 8.82)
# (249, 8.82)
# (250, 8.925)
# (251, 8.925)
# (252, 9.282)
# (253, 9.639)
# (254, 22.218000000000004)
# (255, 25.430999999999997)
# (256, 12.9675)
# (257, 13.671)
# (258, 14.2905)
# (259, 13.8915)
# (260, 12.347999999999999)
# (261, 12.1275)
# (262, 11.025)
# (263, 10.584000000000001)
# (264, 9.24)
# (265, 9.24)
# (266, 9.24)
# (267, 9.24)
# (268, 9.24)
# (269, 9.24)
# (270, 22.1235)
# (271, 25.430999999999997)
# (272, 10.584000000000001)
# (273, 9.702)
# (274, 12.1275)
# (275, 11.466)
# (276, 8.82)
# (277, 8.82)
# (278, 10.142999999999999)
# (279, 10.142999999999999)
# (280, 10.142999999999999)
# (281, 10.142999999999999)
# (282, 10.584000000000001)
# (283, 10.605)
# (284, 11.2245)
# (285, 11.2245)
# (286, 22.9635)
# (287, 24.3075)
# (288, 12.1275)
# (289, 11.2875)
# (290, 10.584000000000001)
# (291, 9.9225)
# (292, 9.4815)
# (293, 9.3975)
# (294, 9.3975)
# (295, 9.3975)
# (296, 9.3975)
# (297, 9.3975)
# (298, 9.4185)
# (299, 9.4815)
# (300, 9.618)
# (301, 10.059)
# (302, 22.5225)
# (303, 23.646)
# (304, 13.9545)
# (305, 12.705)
# (306, 12.1275)
# (307, 11.466)
# (308, 10.584000000000001)
# (309, 10.3635)
# (310, 9.9225)
# (311, 9.9225)
# (312, 9.261000000000001)
# (313, 9.261000000000001)
# (314, 9.261000000000001)
# (315, 9.4815)
# (316, 9.24)
# (317, 9.9225)
# (318, 22.0815)
# (319, 25.389)
# (320, 11.529000000000002)
# (321, 9.681000000000001)
# (322, 10.142999999999999)
# (323, 9.702)
# (324, 9.639)
# (325, 9.639)
# (326, 9.177)
# (327, 9.177)
# (328, 9.261000000000001)
# (329, 9.177)
# (330, 9.4395)
# (331, 9.639)
# (332, 9.219)
# (333, 9.597000000000001)
# (334, 22.1025)
# (335, 22.9635)
# (336, 11.907)
# (337, 11.025)
# (338, 9.9225)
# (339, 9.4815)
# (340, 9.4185)
# (341, 9.3975)
# (342, 9.366)
# (343, 9.261000000000001)
# (344, 9.366)
# (345, 9.0405)
# (346, 9.366)
# (347, 9.366)
# (348, 9.366)
# (349, 10.584000000000001)
# (350, 22.0815)
# (351, 24.7275)
# (352, 14.469000000000001)
# (353, 13.3665)
# (354, 11.109000000000002)
# (355, 10.142999999999999)
# (356, 9.9225)
# (357, 9.702)
# (358, 9.261000000000001)
# (359, 9.261000000000001)
# (360, 9.156)
# (361, 9.156)
# (362, 9.156)
# (363, 9.156)
# (364, 9.156)
# (365, 9.702)
# (366, 21.881999999999998)
# (367, 24.7275)
# (368, 11.2455)
# (369, 10.142999999999999)
# (370, 9.702)
# (371, 8.82)
# (372, 8.5995)
# (373, 8.5995)
# (374, 8.5995)
# (375, 8.5995)
# (376, 8.5995)
# (377, 8.5995)
# (378, 9.261000000000001)
# (379, 9.9225)
# (380, 8.379)
# (381, 9.261000000000001)
# (382, 21.6405)
# (383, 22.0815)
# (384, 10.4265)
# (385, 10.647)
# (386, 11.2455)
# (387, 9.8805)
# (388, 9.0405)
# (389, 8.379)
# (390, 8.883)
# (391, 8.862)
# (392, 8.1585)
# (393, 8.1585)
# (394, 8.1585)
# (395, 8.1585)
# (396, 7.581)
# (397, 7.938)
# (398, 22.0605)
# (399, 22.4805)
# (400, 12.1275)
# (401, 9.8805)
# (402, 9.261000000000001)
# (403, 8.925)
# (404, 8.841000000000001)
# (405, 8.379)
# (406, 8.5995)
# (407, 8.5995)
# (408, 8.379)
# (409, 8.379)
# (410, 8.379)
# (411, 8.379)
# (412, 9.4815)
# (413, 9.4815)
# (414, 23.625)
# (415, 24.066)
# (416, 13.3665)
# (417, 11.109000000000002)
# (418, 9.156)
# (419, 8.883)
# (420, 8.5785)
# (421, 8.5785)
# (422, 8.5785)
# (423, 8.5995)
# (424, 8.5575)
# (425, 8.5575)
# (426, 8.5575)
# (427, 8.799)
# (428, 8.736)
# (429, 8.925)
# (430, 22.0815)
# (431, 25.83)
# (432, 12.347999999999999)
# (433, 10.584000000000001)
# (434, 10.8045)
# (435, 9.4185)
# (436, 9.0615)
# (437, 8.82)
# (438, 8.6205)
# (439, 8.6205)
# (440, 8.6205)
# (441, 8.6205)
# (442, 8.6205)
# (443, 8.799)
# (444, 8.6205)
# (445, 8.862)
# (446, 21.945)
# (447, 25.1265)
# (448, 13.23)
# (449, 11.55)
# (450, 11.466)
# (451, 10.584000000000001)
# (452, 10.142999999999999)
# (453, 10.248)
# (454, 9.786)
# (455, 9.702)
# (456, 9.597000000000001)
# (457, 9.219)
# (458, 9.261000000000001)
# (459, 9.261000000000001)
# (460, 9.302999999999999)
# (461, 10.3425)
# (462, 22.5225)
# (463, 24.7485)
# (464, 13.9335)
# (465, 13.4295)
# (466, 13.0515)
# (467, 12.789000000000001)
# (468, 11.6865)
# (469, 11.6865)
# (470, 11.067)
# (471, 10.7625)
# (472, 9.9645)
# (473, 9.4185)
# (474, 9.9225)
# (475, 9.4395)
# (476, 9.765)
# (477, 10.647)
# (478, 21.903000000000002)
# (479, 25.031999999999996)
# (480, 15.2145)
# (481, 13.671)
# (482, 10.0065)
# (483, 9.24)
# (484, 9.219)
# (485, 9.219)
# (486, 8.484)
# (487, 8.357999999999999)
# (488, 9.156)
# (489, 8.841000000000001)
# (490, 8.5995)
# (491, 8.2425)
# (492, 7.497000000000001)
# (493, 7.6965)
# (494, 20.7585)
# (495, 21.965999999999998)
# (496, 9.261000000000001)
# (497, 9.4395)
# (498, 10.584000000000001)
# (499, 10.3635)
# (500, 9.765)
# (501, 10.668)
# (502, 12.789000000000001)
# (503, 13.23)
# (504, 11.907)
# (505, 11.865)
# (506, 11.466)
# (507, 11.2035)
# (508, 9.9015)
# (509, 11.025)
# (510, 22.743000000000002)
# (511, 24.948)
# (512, 11.7705)
# (513, 10.647)
# (514, 9.702)
# (515, 9.5655)
# (516, 9.261000000000001)
# (517, 9.261000000000001)
# (518, 9.261000000000001)
# (519, 9.261000000000001)
# (520, 8.862)
# (521, 8.862)
# (522, 8.862)
# (523, 9.0615)
# (524, 8.883)
# (525, 9.786)
# (526, 22.0815)
# (527, 24.066)
# (528, 12.789000000000001)
# (529, 9.9225)
# (530, 9.702)
# (531, 9.1245)
# (532, 9.0615)
# (533, 9.0615)
# (534, 9.0615)
# (535, 9.0825)
# (536, 9.702)
# (537, 9.261000000000001)
# (538, 9.366)
# (539, 9.261000000000001)
# (540, 9.0615)
# (541, 9.219)
# (542, 21.965999999999998)
# (543, 23.184)
# (544, 10.668)
# (545, 9.807)
# (546, 10.142999999999999)
# (547, 9.9225)
# (548, 9.5025)
# (549, 9.765)
# (550, 10.3635)
# (551, 10.584000000000001)
# (552, 10.038)
# (553, 10.038)
# (554, 9.9225)
# (555, 9.9225)
# (556, 9.722999999999999)
# (557, 10.3635)
# (558, 22.5225)
# (559, 24.6855)
# (560, 10.3635)
# (561, 10.038)
# (562, 9.4395)
# (563, 9.0825)
# (564, 9.0405)
# (565, 8.9985)
# (566, 8.904)
# (567, 8.925)
# (568, 9.0825)
# (569, 8.777999999999999)
# (570, 9.261000000000001)
# (571, 8.9565)
# (572, 9.0825)
# (573, 9.4815)
# (574, 22.5015)
# (575, 22.9845)
# (576, 13.776)
# (577, 12.789000000000001)
# (578, 10.626)
# (579, 9.4395)
# (580, 8.904)
# (581, 8.904)
# (582, 9.4815)
# (583, 9.261000000000001)
# (584, 8.715)
# (585, 8.715)
# (586, 8.5995)
# (587, 8.484)
# (588, 8.379)
# (589, 8.484)
# (590, 21.315)
# (591, 21.965999999999998)
# (592, 9.618)
# (593, 9.618)
# (594, 9.261000000000001)
# (595, 8.5995)
# (596, 8.5995)
# (597, 8.4)
# (598, 8.5995)
# (599, 8.4)
# (600, 8.5995)
# (601, 8.4)
# (602, 8.5155)
# (603, 8.5155)
# (604, 8.463)
# (605, 8.463)
# (606, 21.84)
# (607, 22.659000000000002)
# (608, 11.907)
# (609, 11.7075)
# (610, 11.2455)
# (611, 9.9225)
# (612, 10.142999999999999)
# (613, 9.261000000000001)
# (614, 9.177)
# (615, 8.5785)
# (616, 7.7175)
# (617, 7.497000000000001)
# (618, 7.7175)
# (619, 7.7175)
# (620, 7.497000000000001)
# (621, 7.7175)
# (622, 20.454)
# (623, 21.861)
# (624, 10.8885)
# (625, 10.059)
# (626, 9.744)
# (627, 9.324)
# (628, 9.765)
# (629, 9.722999999999999)
# (630, 9.702)
# (631, 9.722999999999999)
# (632, 9.66)
# (633, 9.66)
# (634, 9.5655)
# (635, 9.9225)
# (636, 9.744)
# (637, 9.5445)
# (638, 21.945)
# (639, 24.57)
# (640, 11.907)
# (641, 11.13)
# (642, 10.689)
# (643, 11.907)
# (644, 12.347999999999999)
# (645, 12.1275)
# (646, 11.823)
# (647, 11.025)
# (648, 9.765)
# (649, 9.345)
# (650, 9.0405)
# (651, 9.0405)
# (652, 8.82)
# (653, 9.0405)
# (654, 21.42)
# (655, 22.197)
# (656, 11.487)
# (657, 10.059)
# (658, 9.807)
# (659, 9.702)
# (660, 9.4815)
# (661, 9.261000000000001)
# (662, 9.4815)
# (663, 9.4815)
# (664, 9.4815)
# (665, 9.4815)
# (666, 8.82)
# (667, 8.82)
# (668, 8.82)
# (669, 9.302999999999999)
# (670, 21.84)
# (671, 23.184)
# (672, 11.2035)
# (673, 10.142999999999999)
# (674, 9.9225)
# (675, 9.702)
# (676, 9.5025)
# (677, 9.0405)
# (678, 9.4815)
# (679, 8.82)
# (680, 9.261000000000001)
# (681, 8.82)
# (682, 8.5995)
# (683, 8.4)
# (684, 8.442)
# (685, 9.261000000000001)
# (686, 22.0605)
# (687, 22.4805)
# (688, 9.9225)
# (689, 9.702)
# (690, 9.4815)
# (691, 9.261000000000001)
# (692, 9.681000000000001)
# (693, 9.681000000000001)
# (694, 9.702)
# (695, 9.618)
# (696, 9.261000000000001)
# (697, 9.219)
# (698, 8.379)
# (699, 8.379)
# (700, 8.274)
# (701, 8.5995)
# (702, 21.42)
# (703, 22.0815)
# (704, 10.142999999999999)
# (705, 11.466)
# (706, 11.466)
# (707, 11.1615)
# (708, 10.584000000000001)
# (709, 10.584000000000001)
# (710, 10.038)
# (711, 9.702)
# (712, 9.3975)
# (713, 8.841000000000001)
# (714, 8.841000000000001)
# (715, 8.757)
# (716, 8.6835)
# (717, 8.757)
# (718, 21.42)
# (719, 22.5225)
# (720, 9.261000000000001)
# (721, 9.807)
# (722, 10.584000000000001)
# (723, 9.807)
# (724, 10.584000000000001)
# (725, 9.702)
# (726, 9.9435)
# (727, 9.702)
# (728, 9.4605)
# (729, 8.379)
# (730, 8.1585)
# (731, 8.82)
# (732, 8.0745)
# (733, 8.5995)
# (734, 21.861)
# (735, 22.302)
# (736, 11.025)
# (737, 10.142999999999999)
# (738, 10.668)
# (739, 9.8805)
# (740, 10.142999999999999)
# (741, 9.0405)
# (742, 10.227)
# (743, 9.5445)
# (744, 10.3635)
# (745, 10.142999999999999)
# (746, 10.122)
# (747, 9.8805)
# (748, 9.261000000000001)
# (749, 9.9015)
# (750, 21.861)
# (751, 23.184)
# (752, 12.347999999999999)
# (753, 11.2455)
# (754, 10.4475)
# (755, 9.261000000000001)
# (756, 9.261000000000001)
# (757, 9.1035)
# (758, 8.82)
# (759, 8.736)
# (760, 8.4)
# (761, 8.274)
# (762, 8.5995)
# (763, 8.379)
# (764, 8.274)
# (765, 8.82)
# (766, 21.1155)
# (767, 23.184)
# (768, 12.747)
# (769, 12.285)
# (770, 11.2245)
# (771, 9.702)
# (772, 9.807)
# (773, 9.702)
# (774, 9.9225)
# (775, 9.261000000000001)
# (776, 8.379)
# (777, 8.2425)
# (778, 8.1375)
# (779, 8.1165)
# (780, 8.1375)
# (781, 8.2005)
# (782, 20.936999999999998)
# (783, 21.462)
# (784, 10.584000000000001)
# (785, 9.9225)
# (786, 10.3635)
# (787, 9.9225)
# (788, 9.5445)
# (789, 9.4395)
# (790, 9.597000000000001)
# (791, 9.366)
# (792, 9.366)
# (793, 9.156)
# (794, 8.82)
# (795, 8.82)
# (796, 8.82)
# (797, 10.3635)
# (798, 21.6195)
# (799, 24.066)
# (800, 10.2795)
# (801, 9.702)
# (802, 8.6625)
# (803, 8.6625)
# (804, 8.6835)
# (805, 8.6835)
# (806, 9.0615)
# (807, 8.82)
# (808, 8.736)
# (809, 8.736)
# (810, 8.715)
# (811, 8.484)
# (812, 8.6205)
# (813, 8.82)
# (814, 21.6405)
# (815, 21.861)
# (816, 11.025)
# (817, 10.584000000000001)
# (818, 10.8045)
# (819, 9.9225)
# (820, 9.702)
# (821, 9.0405)
# (822, 9.702)
# (823, 8.9775)
# (824, 9.366)
# (825, 8.5155)
# (826, 9.261000000000001)
# (827, 8.82)
# (828, 7.497000000000001)
# (829, 7.497000000000001)
# (830, 21.357)
# (831, 21.861)
# (832, 8.799)
# (833, 8.799)
# (834, 8.0745)
# (835, 7.938)
# (836, 7.1610000000000005)
# (837, 7.056)
# (838, 7.412999999999999)
# (839, 7.2555)
# (840, 7.2765)
# (841, 6.615)
# (842, 6.1739999999999995)
# (843, 6.3735)
# (844, 5.207999999999999)
# (845, 7.013999999999999)
# (846, 20.097)
# (847, 21.1365)
# (848, 9.0405)
# (849, 8.3265)
# (850, 8.421)
# (851, 8.0745)
# (852, 8.4)
# (853, 8.4)
# (854, 9.009)
# (855, 8.1375)
# (856, 9.261000000000001)
# (857, 8.1375)
# (858, 8.82)
# (859, 8.1585)
# (860, 6.8775)
# (861, 7.497000000000001)
# (862, 21.1995)
# (863, 21.756)
# (864, 10.0065)
# (865, 8.379)
# (866, 8.0955)
# (867, 8.0955)
# (868, 8.0955)
# (869, 8.043)
# (870, 8.1165)
# (871, 8.1165)
# (872, 8.2005)
# (873, 8.043)
# (874, 7.98)
# (875, 7.98)
# (876, 7.497000000000001)
# (877, 7.896)
# (878, 21.42)
# (879, 22.365)
# (880, 10.8045)
# (881, 8.82)
# (882, 8.82)
# (883, 8.1585)
# (884, 8.82)
# (885, 8.82)
# (886, 9.261000000000001)
# (887, 8.715)
# (888, 8.0955)
# (889, 7.896)
# (890, 7.896)
# (891, 7.896)
# (892, 7.832999999999999)
# (893, 7.896)
# (894, 20.622)
# (895, 21.315)
# (896, 10.584000000000001)
# (897, 8.379)
# (898, 8.777999999999999)
# (899, 8.2005)
# (900, 9.261000000000001)
# (901, 8.316)
# (902, 8.484)
# (903, 8.2005)
# (904, 8.022)
# (905, 7.98)
# (906, 7.959)
# (907, 7.959)
# (908, 7.959)
# (909, 8.1165)
# (910, 21.1995)
# (911, 22.5225)
# (912, 11.2245)
# (913, 9.4185)
# (914, 8.841000000000001)
# (915, 8.379)
# (916, 8.841000000000001)
# (917, 8.5995)
# (918, 8.6835)
# (919, 8.5995)
# (920, 8.484)
# (921, 8.1585)
# (922, 8.1585)
# (923, 8.1375)
# (924, 8.1585)
# (925, 8.379)
# (926, 21.0)
# (927, 21.42)
# (928, 11.466)
# (929, 10.689)
# (930, 9.702)
# (931, 8.82)
# (932, 7.938)
# (933, 7.8015)
# (934, 7.917000000000001)
# (935, 7.896)
# (936, 7.875)
# (937, 7.497000000000001)
# (938, 7.497000000000001)
# (939, 7.3185)
# (940, 7.497000000000001)
# (941, 7.875)
# (942, 20.6955)
# (943, 21.1995)
# (944, 9.4605)
# (945, 8.379)
# (946, 7.938)
# (947, 7.8015)
# (948, 7.917000000000001)
# (949, 7.896)
# (950, 7.3185)
# (951, 7.056)
# (952, 7.497000000000001)
# (953, 6.615)
# (954, 7.497000000000001)
# (955, 7.875)
# (956, 20.6955)
# (957, 21.1995)
# (958, 20.538)
# (959, 22.5225)
# (960, 8.82)
# (961, 8.4)
# (962, 8.043)
# (963, 8.001)
# (964, 7.7805)
# (965, 7.7805)
# (966, 7.7805)
# (967, 7.7175)
# (968, 7.7175)
# (969, 7.7175)
# (970, 7.7175)
# (971, 7.7175)
# (972, 20.3175)
# (973, 20.979)
# (974, 22.826999999999998)
# (975, 23.625)
# (976, 12.347999999999999)
# (977, 12.1065)
# (978, 11.025)
# (979, 10.3635)
# (980, 8.82)
# (981, 8.379)
# (982, 7.938)
# (983, 7.8015)
# (984, 7.7385)
# (985, 7.7385)
# (986, 7.77)
# (987, 7.854)
# (988, 20.7585)
# (989, 22.743000000000002)
# (990, 23.625)
# (991, 24.7275)
# (992, 10.142999999999999)
# (993, 9.9225)
# (994, 9.3975)
# (995, 9.1245)
# (996, 9.0405)
# (997, 8.736)
# (998, 8.1375)
# (999, 7.938)
# (1000, 7.938)
# (1001, 8.043)
# (1002, 7.938)
# (1003, 8.799)
# (1004, 21.1365)
# (1005, 22.4595)
# (1006, 23.184)
# (1007, 24.066)
# (1008, 11.025)
# (1009, 10.584000000000001)
# (1010, 9.702)
# (1011, 9.4605)
# (1012, 8.379)
# (1013, 8.1585)
# (1014, 7.832999999999999)
# (1015, 7.581)
# (1016, 7.602)
# (1017, 7.602)
# (1018, 7.412999999999999)
# (1019, 7.539)
# (1020, 20.244)
# (1021, 20.7585)
# (1022, 20.979)
# (1023, 21.861)
# (1024, 9.261000000000001)
# (1025, 7.959)
# (1026, 8.1375)
# (1027, 7.875)
# (1028, 7.7805)
# (1029, 7.7175)
# (1030, 7.539)
# (1031, 7.497000000000001)
# (1032, 7.497000000000001)
# (1033, 7.497000000000001)
# (1034, 7.497000000000001)
# (1035, 7.7175)
# (1036, 20.559)
# (1037, 21.861)
# (1038, 21.861)
# (1039, 23.0475)
# (1040, 12.1275)
# (1041, 11.55)
# (1042, 11.571)
# (1043, 11.025)
# (1044, 10.142999999999999)
# (1045, 9.9225)
# (1046, 9.5445)
# (1047, 8.799)
# (1048, 8.736)
# (1049, 8.274)
# (1050, 8.379)
# (1051, 8.9985)
# (1052, 21.861)
# (1053, 23.625)
# (1054, 24.2865)
# (1055, 25.053)
# (1056, 12.411)
# (1057, 12.411)
# (1058, 12.285)
# (1059, 12.285)
# (1060, 11.025)
# (1061, 10.584000000000001)
# (1062, 10.3635)
# (1063, 9.156)
# (1064, 8.5995)
# (1065, 8.5995)
# (1066, 8.6415)
# (1067, 8.9565)
# (1068, 22.743000000000002)
# (1069, 24.7275)
# (1070, 24.7275)
# (1071, 25.305)
# (1072, 13.0095)
# (1073, 12.1275)
# (1074, 12.1275)
# (1075, 11.907)
# (1076, 11.067)
# (1077, 10.8465)
# (1078, 9.9225)
# (1079, 9.4815)
# (1080, 9.1035)
# (1081, 9.1035)
# (1082, 8.5365)
# (1083, 8.82)
# (1084, 21.6825)
# (1085, 23.625)
# (1086, 25.389)
# (1087, 25.851)
# (1088, 13.3665)
# (1089, 12.39)
# (1090, 11.802)
# (1091, 11.6865)
# (1092, 11.6865)
# (1093, 10.5)
# (1094, 9.261000000000001)
# (1095, 8.757)
# (1096, 8.883)
# (1097, 8.777999999999999)
# (1098, 8.799)
# (1099, 8.883)
# (1100, 22.302)
# (1101, 24.7485)
# (1102, 25.473000000000003)
# (1103, 26.0505)
# (1104, 11.907)
# (1105, 10.3635)
# (1106, 10.8045)
# (1107, 9.4815)
# (1108, 9.0615)
# (1109, 8.82)
# (1110, 8.799)
# (1111, 8.736)
# (1112, 8.736)
# (1113, 8.484)
# (1114, 8.484)
# (1115, 8.799)
# (1116, 21.525)
# (1117, 22.0815)
# (1118, 23.4045)
# (1119, 24.948)
# (1120, 12.347999999999999)
# (1121, 11.025)
# (1122, 10.3635)
# (1123, 9.302999999999999)
# (1124, 9.261000000000001)
# (1125, 9.0195)
# (1126, 9.4185)
# (1127, 9.1035)
# (1128, 9.1035)
# (1129, 9.1035)
# (1130, 8.82)
# (1131, 9.261000000000001)
# (1132, 21.6405)
# (1133, 23.625)
# (1134, 24.2865)
# (1135, 25.935)
# (1136, 12.789000000000001)
# (1137, 11.466)
# (1138, 11.7495)
# (1139, 11.2035)
# (1140, 11.2245)
# (1141, 10.584000000000001)
# (1142, 9.702)
# (1143, 9.4815)
# (1144, 9.261000000000001)
# (1145, 9.219)
# (1146, 8.82)
# (1147, 8.925)
# (1148, 21.6405)
# (1149, 22.5855)
# (1150, 22.743000000000002)
# (1151, 24.3495)
# (1152, 11.571)
# (1153, 10.668)
# (1154, 10.2795)
# (1155, 9.4815)
# (1156, 8.715)
# (1157, 8.715)
# (1158, 8.5365)
# (1159, 8.379)
# (1160, 8.0955)
# (1161, 7.938)
# (1162, 7.938)
# (1163, 8.1795)
# (1164, 21.315)
# (1165, 21.861)
# (1166, 22.5225)
# (1167, 23.0475)
# (1168, 10.3635)
# (1169, 9.5025)
# (1170, 9.702)
# (1171, 9.639)
# (1172, 10.8045)
# (1173, 10.584000000000001)
# (1174, 10.520999999999999)
# (1175, 8.757)
# (1176, 8.82)
# (1177, 8.82)
# (1178, 8.715)
# (1179, 8.82)
# (1180, 21.903000000000002)
# (1181, 23.4885)
# (1182, 23.625)
# (1183, 25.0845)
# (1184, 9.9225)
# (1185, 9.1245)
# (1186, 9.261000000000001)
# (1187, 9.198)
# (1188, 8.82)
# (1189, 7.938)
# (1190, 7.7175)
# (1191, 7.7175)
# (1192, 7.7175)
# (1193, 7.7175)
# (1194, 7.497000000000001)
# (1195, 8.357999999999999)
# (1196, 20.958000000000002)
# (1197, 21.819000000000003)
# (1198, 22.302)
# (1199, 23.079)
# (1200, 11.907)
# (1201, 11.025)
# (1202, 11.466)
# (1203, 11.067)
# (1204, 11.025)
# (1205, 10.142999999999999)
# (1206, 9.261000000000001)
# (1207, 8.6205)
# (1208, 8.6835)
# (1209, 8.6205)
# (1210, 8.5995)
# (1211, 8.82)
# (1212, 22.1235)
# (1213, 24.7275)
# (1214, 24.2865)
# (1215, 25.1685)
# (1216, 11.3085)
# (1217, 9.302999999999999)
# (1218, 9.261000000000001)
# (1219, 8.82)
# (1220, 9.4185)
# (1221, 8.379)
# (1222, 8.5995)
# (1223, 8.2215)
# (1224, 8.316)
# (1225, 8.274)
# (1226, 8.1585)
# (1227, 8.379)
# (1228, 21.0)
# (1229, 22.743000000000002)
# (1230, 22.302)
# (1231, 23.625)
# (1232, 9.702)
# (1233, 9.0615)
# (1234, 8.6415)
# (1235, 9.0615)
# (1236, 8.6415)
# (1237, 8.2005)
# (1238, 8.379)
# (1239, 8.2005)
# (1240, 8.2005)
# (1241, 8.2005)
# (1242, 8.1585)
# (1243, 8.274)
# (1244, 20.979)
# (1245, 21.6405)
# (1246, 21.6615)
# (1247, 22.4385)
# (1248, 11.13)
# (1249, 10.3005)
# (1250, 8.379)
# (1251, 8.043)
# (1252, 8.1165)
# (1253, 7.959)
# (1254, 7.959)
# (1255, 7.938)
# (1256, 7.7595)
# (1257, 7.7175)
# (1258, 7.7175)
# (1259, 7.917000000000001)
# (1260, 20.979)
# (1261, 21.1995)
# (1262, 21.6405)
# (1263, 22.302)
# (1264, 11.466)
# (1265, 10.7835)
# (1266, 9.4605)
# (1267, 8.5785)
# (1268, 7.938)
# (1269, 7.392)
# (1270, 7.434)
# (1271, 7.392)
# (1272, 6.615)
# (1273, 6.615)
# (1274, 7.2765)
# (1275, 7.2765)
# (1276, 19.992)
# (1277, 20.3805)
# (1278, 22.5225)
# (1279, 23.3835)
# (1280, 10.7415)
# (1281, 10.3635)
# (1282, 8.82)
# (1283, 8.82)
# (1284, 8.043)
# (1285, 7.896)
# (1286, 8.379)
# (1287, 7.056)
# (1288, 5.5125)
# (1289, 5.0925)
# (1290, 5.0715)
# (1291, 6.1739999999999995)
# (1292, 21.42)
# (1293, 22.5225)
# (1294, 21.378)
# (1295, 22.9215)
# (1296, 10.479000000000001)
# (1297, 9.702)
# (1298, 7.2765)
# (1299, 7.497000000000001)
# (1300, 6.615)
# (1301, 6.1739999999999995)
# (1302, 6.1739999999999995)
# (1303, 6.1739999999999995)
# (1304, 5.5125)
# (1305, 5.4705)
# (1306, 5.733)
# (1307, 6.615)
# (1308, 20.180999999999997)
# (1309, 21.42)
# (1310, 21.42)
# (1311, 22.638)
# (1312, 9.5235)
# (1313, 8.6205)
# (1314, 7.854)
# (1315, 7.854)
# (1316, 7.6965)
# (1317, 7.6545)
# (1318, 7.497000000000001)
# (1319, 7.056)
# (1320, 6.8355)
# (1321, 6.8355)
# (1322, 6.615)
# (1323, 7.854)
# (1324, 20.538)
# (1325, 21.0)
# (1326, 21.42)
# (1327, 22.1235)
# (1328, 9.9225)
# (1329, 9.0195)
# (1330, 7.6755)
# (1331, 7.455)
# (1332, 7.2765)
# (1333, 7.2765)
# (1334, 6.93)
# (1335, 6.72)
# (1336, 6.636)
# (1337, 6.615)
# (1338, 6.615)
# (1339, 7.119)
# (1340, 20.097)
# (1341, 20.979)
# (1342, 21.041999999999998)
# (1343, 22.638)
# (1344, 10.562999999999999)
# (1345, 10.227)
# (1346, 10.4055)
# (1347, 10.2795)
# (1348, 9.4815)
# (1349, 9.4395)
# (1350, 8.82)
# (1351, 8.295)
# (1352, 8.2005)
# (1353, 8.2005)
# (1354, 8.2005)
# (1355, 8.5995)
# (1356, 21.441)
# (1357, 21.7245)
# (1358, 22.8795)
# (1359, 23.982)
# (1360, 9.9645)
# (1361, 8.5995)
# (1362, 8.9985)
# (1363, 8.82)
# (1364, 8.82)
# (1365, 8.1585)
# (1366, 8.1585)
# (1367, 7.938)
# (1368, 7.7175)
# (1369, 7.7175)
# (1370, 7.917000000000001)
# (1371, 7.938)
# (1372, 21.021)
# (1373, 21.357)
# (1374, 22.197)
# (1375, 22.197)
# (1376, 11.025)
# (1377, 10.92)
# (1378, 11.2035)
# (1379, 10.8465)
# (1380, 9.8385)
# (1381, 9.156)
# (1382, 8.2005)
# (1383, 7.497000000000001)
# (1384, 7.2765)
# (1385, 7.2765)
# (1386, 7.2765)
# (1387, 7.2765)
# (1388, 20.097)
# (1389, 20.7585)
# (1390, 20.7585)
# (1391, 22.5645)
# (1392, 9.9855)
# (1393, 10.206)
# (1394, 10.8465)
# (1395, 10.584000000000001)
# (1396, 10.4265)
# (1397, 10.142999999999999)
# (1398, 10.584000000000001)
# (1399, 10.584000000000001)
# (1400, 10.4265)
# (1401, 10.142999999999999)
# (1402, 7.938)
# (1403, 8.5785)
# (1404, 21.42)
# (1405, 23.541)
# (1406, 23.561999999999998)
# (1407, 24.506999999999998)
# (1408, 11.13)
# (1409, 10.5)
# (1410, 9.9225)
# (1411, 9.597000000000001)
# (1412, 9.282)
# (1413, 8.82)
# (1414, 8.82)
# (1415, 8.379)
# (1416, 7.8015)
# (1417, 7.6965)
# (1418, 7.6965)
# (1419, 8.001)
# (1420, 20.475)
# (1421, 22.302)
# (1422, 22.302)
# (1423, 23.625)
# (1424, 10.142999999999999)
# (1425, 8.379)
# (1426, 8.357999999999999)
# (1427, 8.1585)
# (1428, 8.4)
# (1429, 8.1585)
# (1430, 8.1585)
# (1431, 8.1585)
# (1432, 8.1585)
# (1433, 8.1585)
# (1434, 8.1165)
# (1435, 8.1585)
# (1436, 21.315)
# (1437, 23.625)
# (1438, 24.15)
# (1439, 25.2315)
# (1440, 12.894)
# (1441, 11.907)
# (1442, 11.7285)
# (1443, 11.1615)
# (1444, 11.2455)
# (1445, 10.7205)
# (1446, 9.807)
# (1447, 9.261000000000001)
# (1448, 8.6835)
# (1449, 8.337)
# (1450, 8.1585)
# (1451, 9.177)
# (1452, 22.323)
# (1453, 24.444000000000003)
# (1454, 23.8665)
# (1455, 24.7905)
# (1456, 8.82)
# (1457, 7.938)
# (1458, 8.0955)
# (1459, 7.938)
# (1460, 8.6415)
# (1461, 7.938)
# (1462, 8.379)
# (1463, 7.938)
# (1464, 7.938)
# (1465, 7.938)
# (1466, 7.917000000000001)
# (1467, 8.379)
# (1468, 21.1785)
# (1469, 22.638)
# (1470, 23.184)
# (1471, 24.066)
# (1472, 12.012)
# (1473, 11.466)
# (1474, 10.8675)
# (1475, 10.4475)
# (1476, 10.584000000000001)
# (1477, 9.702)
# (1478, 9.4815)
# (1479, 8.82)
# (1480, 8.1585)
# (1481, 8.1585)
# (1482, 7.959)
# (1483, 8.1585)
# (1484, 20.6745)
# (1485, 22.0815)
# (1486, 21.945)
# (1487, 22.302)
# (1488, 8.5365)
# (1489, 7.056)
# (1490, 7.938)
# (1491, 7.602)
# (1492, 8.379)
# (1493, 7.497000000000001)
# (1494, 6.9510000000000005)
# (1495, 6.9510000000000005)
# (1496, 6.9510000000000005)
# (1497, 6.9510000000000005)
# (1498, 6.72)
# (1499, 7.476)
# (1500, 19.572)
# (1501, 20.559)
# (1502, 21.315)
# (1503, 22.4805)
# (1504, 9.702)
# (1505, 9.282)
# (1506, 9.9225)
# (1507, 9.744)
# (1508, 10.7835)
# (1509, 10.2795)
# (1510, 9.9855)
# (1511, 9.702)
# (1512, 8.82)
# (1513, 8.82)
# (1514, 9.702)
# (1515, 9.744)
# (1516, 22.302)
# (1517, 22.826999999999998)
# (1518, 22.5225)
# (1519, 23.73)
# (1520, 9.0405)
# (1521, 9.261000000000001)
# (1522, 10.142999999999999)
# (1523, 9.9225)
# (1524, 10.584000000000001)
# (1525, 10.185)
# (1526, 10.142999999999999)
# (1527, 8.82)
# (1528, 9.261000000000001)
# (1529, 9.66)
# (1530, 8.82)
# (1531, 9.1035)
# (1532, 22.0815)
# (1533, 23.3835)
# (1534, 22.9635)
# (1535, 24.7275)
# (1536, 11.6655)
# (1537, 10.940999999999999)
# (1538, 10.584000000000001)
# (1539, 10.584000000000001)
# (1540, 11.025)
# (1541, 9.9225)
# (1542, 9.618)
# (1543, 8.82)
# (1544, 9.0405)
# (1545, 8.862)
# (1546, 8.379)
# (1547, 9.9225)
# (1548, 22.5225)
# (1549, 24.2865)
# (1550, 23.9085)
# (1551, 25.031999999999996)
# (1552, 9.9015)
# (1553, 8.82)
# (1554, 8.82)
# (1555, 8.5995)
# (1556, 9.0195)
# (1557, 8.715)
# (1558, 8.5575)
# (1559, 8.295)
# (1560, 8.022)
# (1561, 8.379)
# (1562, 8.022)
# (1563, 8.421)
# (1564, 21.084)
# (1565, 22.9635)
# (1566, 22.5225)
# (1567, 23.625)
# (1568, 10.584000000000001)
# (1569, 9.261000000000001)
# (1570, 9.702)
# (1571, 9.0615)
# (1572, 9.744)
# (1573, 8.5995)
# (1574, 9.261000000000001)
# (1575, 8.5995)
# (1576, 8.82)
# (1577, 8.5995)
# (1578, 8.841000000000001)
# (1579, 9.9225)
# (1580, 22.638)
# (1581, 24.506999999999998)
# (1582, 24.506999999999998)
# (1583, 25.284000000000002)
# (1584, 11.907)
# (1585, 10.584000000000001)
# (1586, 11.025)
# (1587, 10.3635)
# (1588, 10.940999999999999)
# (1589, 9.9225)
# (1590, 9.702)
# (1591, 8.736)
# (1592, 8.6625)
# (1593, 8.463)
# (1594, 8.1795)
# (1595, 8.5365)
# (1596, 21.42)
# (1597, 24.2865)
# (1598, 24.066)
# (1599, 25.6305)
# (1600, 12.5685)
# (1601, 12.264000000000001)
# (1602, 11.2875)
# (1603, 10.7205)
# (1604, 11.046)
# (1605, 10.142999999999999)
# (1606, 10.142999999999999)
# (1607, 8.0955)
# (1608, 8.379)
# (1609, 7.98)
# (1610, 7.7175)
# (1611, 7.938)
# (1612, 20.097)
# (1613, 21.1575)
# (1614, 21.6405)
# (1615, 23.4885)
# (1616, 10.479000000000001)
# (1617, 9.9225)
# (1618, 10.7835)
# (1619, 10.584000000000001)
# (1620, 10.3215)
# (1621, 9.9225)
# (1622, 8.925)
# (1623, 8.2005)
# (1624, 8.1795)
# (1625, 8.1585)
# (1626, 7.7175)
# (1627, 8.1795)
# (1628, 21.6405)
# (1629, 22.5225)
# (1630, 22.4595)
# (1631, 22.5855)
# (1632, 8.82)
# (1633, 8.357999999999999)
# (1634, 8.295)
# (1635, 8.295)
# (1636, 8.1795)
# (1637, 7.7805)
# (1638, 7.938)
# (1639, 7.392)
# (1640, 8.1585)
# (1641, 7.392)
# (1642, 7.497000000000001)
# (1643, 7.497000000000001)
# (1644, 20.559)
# (1645, 21.903000000000002)
# (1646, 23.4255)
# (1647, 24.528000000000002)
# (1648, 8.337)
# (1649, 7.7805)
# (1650, 7.832999999999999)
# (1651, 7.7385)
# (1652, 7.7805)
# (1653, 7.7175)
# (1654, 7.602)
# (1655, 7.497000000000001)
# (1656, 7.497000000000001)
# (1657, 7.497000000000001)
# (1658, 7.2765)
# (1659, 7.6545)
# (1660, 20.538)
# (1661, 21.063000000000002)
# (1662, 21.776999999999997)
# (1663, 23.184)
# (1664, 8.043)
# (1665, 7.602)
# (1666, 7.6335)
# (1667, 7.6335)
# (1668, 7.938)
# (1669, 7.581)
# (1670, 7.56)
# (1671, 7.539)
# (1672, 7.476)
# (1673, 7.476)
# (1674, 7.2765)
# (1675, 7.581)
# (1676, 20.3385)
# (1677, 20.538)
# (1678, 21.378)
# (1679, 22.1235)

# %%
for number in enumerate(export_price_value):
    print(number)
# Out:
# (0, 7.6)
# (1, 7.24)
# (2, 7.11)
# (3, 6.7)
# (4, 6.81)
# (5, 6.38)
# (6, 6.58)
# (7, 6.32)
# (8, 6.94)
# (9, 6.57)
# (10, 6.57)
# (11, 6.38)
# (12, 6.14)
# (13, 6.75)
# (14, 13.13)
# (15, 14.37)
# (16, 7.63)
# (17, 7.51)
# (18, 7.75)
# (19, 7.51)
# (20, 7.81)
# (21, 7.73)
# (22, 7.69)
# (23, 7.41)
# (24, 7.22)
# (25, 6.82)
# (26, 6.83)
# (27, 6.48)
# (28, 6.19)
# (29, 6.76)
# (30, 13.24)
# (31, 14.23)
# (32, 6.28)
# (33, 6.57)
# (34, 6.87)
# (35, 6.05)
# (36, 6.1)
# (37, 5.81)
# (38, 5.87)
# (39, 5.81)
# (40, 5.91)
# (41, 5.81)
# (42, 5.75)
# (43, 5.31)
# (44, 5.29)
# (45, 5.29)
# (46, 12.68)
# (47, 14.37)
# (48, 5.41)
# (49, 5.58)
# (50, 5.91)
# (51, 5.81)
# (52, 5.81)
# (53, 5.77)
# (54, 5.81)
# (55, 6.0)
# (56, 6.18)
# (57, 6.1)
# (58, 6.19)
# (59, 5.97)
# (60, 5.19)
# (61, 5.47)
# (62, 12.97)
# (63, 14.56)
# (64, 6.53)
# (65, 6.87)
# (66, 6.87)
# (67, 6.16)
# (68, 6.38)
# (69, 6.1)
# (70, 6.1)
# (71, 5.94)
# (72, 6.1)
# (73, 5.96)
# (74, 6.1)
# (75, 6.12)
# (76, 5.8)
# (77, 6.47)
# (78, 12.9)
# (79, 14.03)
# (80, 6.94)
# (81, 6.51)
# (82, 6.48)
# (83, 5.72)
# (84, 5.88)
# (85, 5.63)
# (86, 5.71)
# (87, 5.63)
# (88, 5.96)
# (89, 5.63)
# (90, 5.88)
# (91, 5.63)
# (92, 5.73)
# (93, 6.57)
# (94, 12.68)
# (95, 13.99)
# (96, 6.35)
# (97, 5.83)
# (98, 6.07)
# (99, 5.53)
# (100, 5.59)
# (101, 5.27)
# (102, 5.27)
# (103, 5.27)
# (104, 5.47)
# (105, 5.27)
# (106, 5.49)
# (107, 5.46)
# (108, 5.41)
# (109, 6.0)
# (110, 12.68)
# (111, 14.18)
# (112, 6.75)
# (113, 6.28)
# (114, 6.0)
# (115, 5.91)
# (116, 5.44)
# (117, 5.32)
# (118, 5.16)
# (119, 5.16)
# (120, 5.25)
# (121, 5.16)
# (122, 5.32)
# (123, 5.25)
# (124, 5.31)
# (125, 5.31)
# (126, 12.43)
# (127, 13.62)
# (128, 6.1)
# (129, 6.1)
# (130, 6.66)
# (131, 6.47)
# (132, 6.45)
# (133, 6.4)
# (134, 6.11)
# (135, 5.63)
# (136, 5.59)
# (137, 5.34)
# (138, 5.46)
# (139, 5.21)
# (140, 5.18)
# (141, 5.57)
# (142, 12.4)
# (143, 13.43)
# (144, 5.81)
# (145, 5.81)
# (146, 5.63)
# (147, 5.36)
# (148, 5.52)
# (149, 5.39)
# (150, 5.44)
# (151, 5.25)
# (152, 5.43)
# (153, 5.26)
# (154, 5.44)
# (155, 5.06)
# (156, 4.99)
# (157, 4.86)
# (158, 12.2)
# (159, 12.93)
# (160, 6.57)
# (161, 6.89)
# (162, 7.32)
# (163, 7.13)
# (164, 6.69)
# (165, 6.58)
# (166, 6.38)
# (167, 6.27)
# (168, 5.14)
# (169, 5.04)
# (170, 5.05)
# (171, 5.04)
# (172, 5.01)
# (173, 5.14)
# (174, 12.24)
# (175, 13.62)
# (176, 7.13)
# (177, 6.57)
# (178, 6.66)
# (179, 6.19)
# (180, 5.91)
# (181, 5.72)
# (182, 6.0)
# (183, 5.74)
# (184, 5.9)
# (185, 5.81)
# (186, 5.63)
# (187, 5.78)
# (188, 5.22)
# (189, 6.53)
# (190, 13.15)
# (191, 14.93)
# (192, 6.05)
# (193, 5.79)
# (194, 6.05)
# (195, 5.53)
# (196, 5.25)
# (197, 5.12)
# (198, 5.14)
# (199, 5.0)
# (200, 5.18)
# (201, 5.18)
# (202, 5.19)
# (203, 5.19)
# (204, 5.18)
# (205, 5.81)
# (206, 12.12)
# (207, 13.43)
# (208, 6.47)
# (209, 5.81)
# (210, 5.83)
# (211, 5.14)
# (212, 5.15)
# (213, 4.96)
# (214, 4.93)
# (215, 4.93)
# (216, 4.87)
# (217, 4.87)
# (218, 4.93)
# (219, 4.93)
# (220, 4.95)
# (221, 5.1)
# (222, 12.39)
# (223, 13.27)
# (224, 6.48)
# (225, 5.26)
# (226, 5.62)
# (227, 5.25)
# (228, 5.26)
# (229, 4.94)
# (230, 4.86)
# (231, 4.86)
# (232, 4.86)
# (233, 4.86)
# (234, 4.87)
# (235, 4.86)
# (236, 4.94)
# (237, 5.33)
# (238, 12.04)
# (239, 13.33)
# (240, 6.6)
# (241, 5.81)
# (242, 5.63)
# (243, 4.96)
# (244, 4.87)
# (245, 4.83)
# (246, 4.73)
# (247, 4.73)
# (248, 4.69)
# (249, 4.69)
# (250, 4.73)
# (251, 4.73)
# (252, 4.88)
# (253, 5.03)
# (254, 12.07)
# (255, 13.45)
# (256, 6.45)
# (257, 6.75)
# (258, 7.02)
# (259, 6.85)
# (260, 6.19)
# (261, 6.1)
# (262, 5.63)
# (263, 5.44)
# (264, 4.86)
# (265, 4.86)
# (266, 4.86)
# (267, 4.86)
# (268, 4.86)
# (269, 4.86)
# (270, 12.04)
# (271, 13.45)
# (272, 5.44)
# (273, 5.06)
# (274, 6.1)
# (275, 5.81)
# (276, 4.69)
# (277, 4.69)
# (278, 5.25)
# (279, 5.25)
# (280, 5.25)
# (281, 5.25)
# (282, 5.44)
# (283, 5.45)
# (284, 5.71)
# (285, 5.71)
# (286, 12.39)
# (287, 12.97)
# (288, 6.1)
# (289, 5.74)
# (290, 5.44)
# (291, 5.16)
# (292, 4.97)
# (293, 4.93)
# (294, 4.93)
# (295, 4.93)
# (296, 4.93)
# (297, 4.93)
# (298, 4.94)
# (299, 4.97)
# (300, 5.02)
# (301, 5.21)
# (302, 12.2)
# (303, 12.68)
# (304, 6.88)
# (305, 6.34)
# (306, 6.1)
# (307, 5.81)
# (308, 5.44)
# (309, 5.34)
# (310, 5.16)
# (311, 5.16)
# (312, 4.87)
# (313, 4.87)
# (314, 4.87)
# (315, 4.97)
# (316, 4.86)
# (317, 5.16)
# (318, 12.02)
# (319, 13.43)
# (320, 5.84)
# (321, 5.05)
# (322, 5.25)
# (323, 5.06)
# (324, 5.03)
# (325, 5.03)
# (326, 4.84)
# (327, 4.84)
# (328, 4.87)
# (329, 4.84)
# (330, 4.95)
# (331, 5.03)
# (332, 4.86)
# (333, 5.02)
# (334, 12.03)
# (335, 12.39)
# (336, 6.0)
# (337, 5.63)
# (338, 5.16)
# (339, 4.97)
# (340, 4.94)
# (341, 4.93)
# (342, 4.92)
# (343, 4.87)
# (344, 4.92)
# (345, 4.78)
# (346, 4.92)
# (347, 4.92)
# (348, 4.92)
# (349, 5.44)
# (350, 12.02)
# (351, 13.15)
# (352, 7.09)
# (353, 6.62)
# (354, 5.66)
# (355, 5.25)
# (356, 5.16)
# (357, 5.06)
# (358, 4.87)
# (359, 4.87)
# (360, 4.83)
# (361, 4.83)
# (362, 4.83)
# (363, 4.83)
# (364, 4.83)
# (365, 5.06)
# (366, 11.93)
# (367, 13.15)
# (368, 5.72)
# (369, 5.25)
# (370, 5.06)
# (371, 4.69)
# (372, 4.59)
# (373, 4.59)
# (374, 4.59)
# (375, 4.59)
# (376, 4.59)
# (377, 4.59)
# (378, 4.87)
# (379, 5.16)
# (380, 4.5)
# (381, 4.87)
# (382, 11.83)
# (383, 12.02)
# (384, 5.37)
# (385, 5.47)
# (386, 5.72)
# (387, 5.14)
# (388, 4.78)
# (389, 4.5)
# (390, 4.71)
# (391, 4.71)
# (392, 4.4)
# (393, 4.4)
# (394, 4.4)
# (395, 4.4)
# (396, 4.16)
# (397, 4.31)
# (398, 12.01)
# (399, 12.19)
# (400, 6.1)
# (401, 5.14)
# (402, 4.87)
# (403, 4.73)
# (404, 4.7)
# (405, 4.5)
# (406, 4.59)
# (407, 4.59)
# (408, 4.5)
# (409, 4.5)
# (410, 4.5)
# (411, 4.5)
# (412, 4.97)
# (413, 4.97)
# (414, 12.68)
# (415, 12.86)
# (416, 6.62)
# (417, 5.66)
# (418, 4.83)
# (419, 4.71)
# (420, 4.58)
# (421, 4.58)
# (422, 4.58)
# (423, 4.59)
# (424, 4.57)
# (425, 4.57)
# (426, 4.57)
# (427, 4.68)
# (428, 4.65)
# (429, 4.73)
# (430, 12.02)
# (431, 13.62)
# (432, 6.19)
# (433, 5.44)
# (434, 5.53)
# (435, 4.94)
# (436, 4.79)
# (437, 4.69)
# (438, 4.6)
# (439, 4.6)
# (440, 4.6)
# (441, 4.6)
# (442, 4.6)
# (443, 4.68)
# (444, 4.6)
# (445, 4.71)
# (446, 11.96)
# (447, 13.31)
# (448, 6.57)
# (449, 5.85)
# (450, 5.81)
# (451, 5.44)
# (452, 5.25)
# (453, 5.3)
# (454, 5.1)
# (455, 5.06)
# (456, 5.02)
# (457, 4.86)
# (458, 4.87)
# (459, 4.87)
# (460, 4.89)
# (461, 5.33)
# (462, 12.2)
# (463, 13.15)
# (464, 6.87)
# (465, 6.65)
# (466, 6.49)
# (467, 6.38)
# (468, 5.91)
# (469, 5.91)
# (470, 5.65)
# (471, 5.51)
# (472, 5.18)
# (473, 4.94)
# (474, 5.16)
# (475, 4.95)
# (476, 5.09)
# (477, 5.47)
# (478, 11.94)
# (479, 13.28)
# (480, 7.41)
# (481, 6.75)
# (482, 5.19)
# (483, 4.86)
# (484, 4.86)
# (485, 4.86)
# (486, 4.55)
# (487, 4.49)
# (488, 4.83)
# (489, 4.7)
# (490, 4.59)
# (491, 4.44)
# (492, 4.12)
# (493, 4.21)
# (494, 11.45)
# (495, 11.97)
# (496, 4.87)
# (497, 4.95)
# (498, 5.44)
# (499, 5.34)
# (500, 5.09)
# (501, 5.48)
# (502, 6.38)
# (503, 6.57)
# (504, 6.0)
# (505, 5.98)
# (506, 5.81)
# (507, 5.7)
# (508, 5.15)
# (509, 5.63)
# (510, 12.3)
# (511, 13.24)
# (512, 5.95)
# (513, 5.47)
# (514, 5.06)
# (515, 5.01)
# (516, 4.87)
# (517, 4.87)
# (518, 4.87)
# (519, 4.87)
# (520, 4.71)
# (521, 4.71)
# (522, 4.71)
# (523, 4.79)
# (524, 4.71)
# (525, 5.1)
# (526, 12.02)
# (527, 12.86)
# (528, 6.38)
# (529, 5.16)
# (530, 5.06)
# (531, 4.82)
# (532, 4.79)
# (533, 4.79)
# (534, 4.79)
# (535, 4.8)
# (536, 5.06)
# (537, 4.87)
# (538, 4.92)
# (539, 4.87)
# (540, 4.79)
# (541, 4.86)
# (542, 11.97)
# (543, 12.49)
# (544, 5.48)
# (545, 5.11)
# (546, 5.25)
# (547, 5.16)
# (548, 4.98)
# (549, 5.09)
# (550, 5.34)
# (551, 5.44)
# (552, 5.2)
# (553, 5.2)
# (554, 5.16)
# (555, 5.16)
# (556, 5.07)
# (557, 5.34)
# (558, 12.2)
# (559, 13.13)
# (560, 5.34)
# (561, 5.2)
# (562, 4.95)
# (563, 4.8)
# (564, 4.78)
# (565, 4.76)
# (566, 4.72)
# (567, 4.73)
# (568, 4.8)
# (569, 4.67)
# (570, 4.87)
# (571, 4.74)
# (572, 4.8)
# (573, 4.97)
# (574, 12.2)
# (575, 12.4)
# (576, 6.8)
# (577, 6.38)
# (578, 5.46)
# (579, 4.95)
# (580, 4.72)
# (581, 4.72)
# (582, 4.97)
# (583, 4.87)
# (584, 4.64)
# (585, 4.64)
# (586, 4.59)
# (587, 4.55)
# (588, 4.5)
# (589, 4.55)
# (590, 11.69)
# (591, 11.97)
# (592, 5.02)
# (593, 5.02)
# (594, 4.87)
# (595, 4.59)
# (596, 4.59)
# (597, 4.51)
# (598, 4.59)
# (599, 4.51)
# (600, 4.59)
# (601, 4.51)
# (602, 4.55)
# (603, 4.55)
# (604, 4.54)
# (605, 4.54)
# (606, 11.91)
# (607, 12.26)
# (608, 6.0)
# (609, 5.92)
# (610, 5.72)
# (611, 5.16)
# (612, 5.25)
# (613, 4.87)
# (614, 4.84)
# (615, 4.58)
# (616, 4.22)
# (617, 4.12)
# (618, 4.22)
# (619, 4.22)
# (620, 4.12)
# (621, 4.22)
# (622, 11.32)
# (623, 11.92)
# (624, 5.57)
# (625, 5.21)
# (626, 5.08)
# (627, 4.9)
# (628, 5.09)
# (629, 5.07)
# (630, 5.06)
# (631, 5.07)
# (632, 5.04)
# (633, 5.04)
# (634, 5.01)
# (635, 5.16)
# (636, 5.08)
# (637, 5.0)
# (638, 11.96)
# (639, 13.08)
# (640, 6.0)
# (641, 5.67)
# (642, 5.49)
# (643, 6.0)
# (644, 6.19)
# (645, 6.1)
# (646, 5.96)
# (647, 5.63)
# (648, 5.09)
# (649, 4.91)
# (650, 4.78)
# (651, 4.78)
# (652, 4.69)
# (653, 4.78)
# (654, 11.73)
# (655, 12.06)
# (656, 5.82)
# (657, 5.21)
# (658, 5.11)
# (659, 5.06)
# (660, 4.97)
# (661, 4.87)
# (662, 4.97)
# (663, 4.97)
# (664, 4.97)
# (665, 4.97)
# (666, 4.69)
# (667, 4.69)
# (668, 4.69)
# (669, 4.89)
# (670, 11.91)
# (671, 12.49)
# (672, 5.7)
# (673, 5.25)
# (674, 5.16)
# (675, 5.06)
# (676, 4.98)
# (677, 4.78)
# (678, 4.97)
# (679, 4.69)
# (680, 4.87)
# (681, 4.69)
# (682, 4.59)
# (683, 4.51)
# (684, 4.53)
# (685, 4.87)
# (686, 12.01)
# (687, 12.19)
# (688, 5.16)
# (689, 5.06)
# (690, 4.97)
# (691, 4.87)
# (692, 5.05)
# (693, 5.05)
# (694, 5.06)
# (695, 5.02)
# (696, 4.87)
# (697, 4.86)
# (698, 4.5)
# (699, 4.5)
# (700, 4.45)
# (701, 4.59)
# (702, 11.73)
# (703, 12.02)
# (704, 5.25)
# (705, 5.81)
# (706, 5.81)
# (707, 5.68)
# (708, 5.44)
# (709, 5.44)
# (710, 5.2)
# (711, 5.06)
# (712, 4.93)
# (713, 4.7)
# (714, 4.7)
# (715, 4.66)
# (716, 4.63)
# (717, 4.66)
# (718, 11.73)
# (719, 12.2)
# (720, 4.87)
# (721, 5.11)
# (722, 5.44)
# (723, 5.11)
# (724, 5.44)
# (725, 5.06)
# (726, 5.17)
# (727, 5.06)
# (728, 4.96)
# (729, 4.5)
# (730, 4.4)
# (731, 4.69)
# (732, 4.37)
# (733, 4.59)
# (734, 11.92)
# (735, 12.11)
# (736, 5.63)
# (737, 5.25)
# (738, 5.48)
# (739, 5.14)
# (740, 5.25)
# (741, 4.78)
# (742, 5.29)
# (743, 5.0)
# (744, 5.34)
# (745, 5.25)
# (746, 5.24)
# (747, 5.14)
# (748, 4.87)
# (749, 5.15)
# (750, 11.92)
# (751, 12.49)
# (752, 6.19)
# (753, 5.72)
# (754, 5.38)
# (755, 4.87)
# (756, 4.87)
# (757, 4.81)
# (758, 4.69)
# (759, 4.65)
# (760, 4.51)
# (761, 4.45)
# (762, 4.59)
# (763, 4.5)
# (764, 4.45)
# (765, 4.69)
# (766, 11.6)
# (767, 12.49)
# (768, 6.36)
# (769, 6.16)
# (770, 5.71)
# (771, 5.06)
# (772, 5.11)
# (773, 5.06)
# (774, 5.16)
# (775, 4.87)
# (776, 4.5)
# (777, 4.44)
# (778, 4.39)
# (779, 4.39)
# (780, 4.39)
# (781, 4.42)
# (782, 11.53)
# (783, 11.75)
# (784, 5.44)
# (785, 5.16)
# (786, 5.34)
# (787, 5.16)
# (788, 5.0)
# (789, 4.95)
# (790, 5.02)
# (791, 4.92)
# (792, 4.92)
# (793, 4.83)
# (794, 4.69)
# (795, 4.69)
# (796, 4.69)
# (797, 5.34)
# (798, 11.82)
# (799, 12.86)
# (800, 5.31)
# (801, 5.06)
# (802, 4.62)
# (803, 4.62)
# (804, 4.63)
# (805, 4.63)
# (806, 4.79)
# (807, 4.69)
# (808, 4.65)
# (809, 4.65)
# (810, 4.64)
# (811, 4.55)
# (812, 4.6)
# (813, 4.69)
# (814, 11.83)
# (815, 11.92)
# (816, 5.63)
# (817, 5.44)
# (818, 5.53)
# (819, 5.16)
# (820, 5.06)
# (821, 4.78)
# (822, 5.06)
# (823, 4.75)
# (824, 4.92)
# (825, 4.55)
# (826, 4.87)
# (827, 4.69)
# (828, 4.12)
# (829, 4.12)
# (830, 11.71)
# (831, 11.92)
# (832, 4.68)
# (833, 4.68)
# (834, 4.37)
# (835, 4.31)
# (836, 3.98)
# (837, 3.93)
# (838, 4.08)
# (839, 4.02)
# (840, 4.03)
# (841, 3.75)
# (842, 3.56)
# (843, 3.64)
# (844, 3.14)
# (845, 3.92)
# (846, 11.17)
# (847, 11.61)
# (848, 4.78)
# (849, 4.47)
# (850, 4.52)
# (851, 4.37)
# (852, 4.51)
# (853, 4.51)
# (854, 4.77)
# (855, 4.39)
# (856, 4.87)
# (857, 4.39)
# (858, 4.69)
# (859, 4.4)
# (860, 3.86)
# (861, 4.12)
# (862, 11.64)
# (863, 11.88)
# (864, 5.19)
# (865, 4.5)
# (866, 4.38)
# (867, 4.38)
# (868, 4.38)
# (869, 4.36)
# (870, 4.39)
# (871, 4.39)
# (872, 4.42)
# (873, 4.36)
# (874, 4.33)
# (875, 4.33)
# (876, 4.12)
# (877, 4.29)
# (878, 11.73)
# (879, 12.14)
# (880, 5.53)
# (881, 4.69)
# (882, 4.69)
# (883, 4.4)
# (884, 4.69)
# (885, 4.69)
# (886, 4.87)
# (887, 4.64)
# (888, 4.38)
# (889, 4.29)
# (890, 4.29)
# (891, 4.29)
# (892, 4.26)
# (893, 4.29)
# (894, 11.4)
# (895, 11.69)
# (896, 5.44)
# (897, 4.5)
# (898, 4.67)
# (899, 4.42)
# (900, 4.87)
# (901, 4.47)
# (902, 4.55)
# (903, 4.42)
# (904, 4.35)
# (905, 4.33)
# (906, 4.32)
# (907, 4.32)
# (908, 4.32)
# (909, 4.39)
# (910, 11.64)
# (911, 12.2)
# (912, 5.71)
# (913, 4.94)
# (914, 4.7)
# (915, 4.5)
# (916, 4.7)
# (917, 4.59)
# (918, 4.63)
# (919, 4.59)
# (920, 4.55)
# (921, 4.4)
# (922, 4.4)
# (923, 4.39)
# (924, 4.4)
# (925, 4.5)
# (926, 11.56)
# (927, 11.73)
# (928, 5.81)
# (929, 5.49)
# (930, 5.06)
# (931, 4.69)
# (932, 4.31)
# (933, 4.25)
# (934, 4.3)
# (935, 4.29)
# (936, 4.28)
# (937, 4.12)
# (938, 4.12)
# (939, 4.05)
# (940, 4.12)
# (941, 4.28)
# (942, 11.42)
# (943, 11.64)
# (944, 4.5)
# (945, 4.69)
# (946, 4.96)
# (947, 4.5)
# (948, 4.31)
# (949, 4.25)
# (950, 4.3)
# (951, 4.29)
# (952, 4.05)
# (953, 3.93)
# (954, 4.12)
# (955, 3.75)
# (956, 4.12)
# (957, 4.28)
# (958, 11.42)
# (959, 11.64)
# (960, 6.1)
# (961, 5.34)
# (962, 4.69)
# (963, 4.51)
# (964, 4.36)
# (965, 4.34)
# (966, 4.24)
# (967, 4.24)
# (968, 4.24)
# (969, 4.22)
# (970, 4.22)
# (971, 4.22)
# (972, 4.22)
# (973, 4.22)
# (974, 11.26)
# (975, 11.55)
# (976, 6.57)
# (977, 6.1)
# (978, 6.19)
# (979, 6.09)
# (980, 5.63)
# (981, 5.34)
# (982, 4.69)
# (983, 4.5)
# (984, 4.31)
# (985, 4.25)
# (986, 4.23)
# (987, 4.23)
# (988, 4.24)
# (989, 4.27)
# (990, 11.45)
# (991, 12.3)
# (992, 5.38)
# (993, 4.76)
# (994, 5.25)
# (995, 5.16)
# (996, 4.93)
# (997, 4.82)
# (998, 4.78)
# (999, 4.65)
# (1000, 4.39)
# (1001, 4.31)
# (1002, 4.31)
# (1003, 4.36)
# (1004, 4.31)
# (1005, 4.68)
# (1006, 11.61)
# (1007, 12.18)
# (1008, 5.81)
# (1009, 5.81)
# (1010, 5.63)
# (1011, 5.44)
# (1012, 5.06)
# (1013, 4.96)
# (1014, 4.5)
# (1015, 4.4)
# (1016, 4.26)
# (1017, 4.16)
# (1018, 4.17)
# (1019, 4.17)
# (1020, 4.08)
# (1021, 4.14)
# (1022, 11.23)
# (1023, 11.45)
# (1024, 5.4)
# (1025, 4.8)
# (1026, 4.87)
# (1027, 4.32)
# (1028, 4.39)
# (1029, 4.28)
# (1030, 4.24)
# (1031, 4.22)
# (1032, 4.14)
# (1033, 4.12)
# (1034, 4.12)
# (1035, 4.12)
# (1036, 4.12)
# (1037, 4.22)
# (1038, 11.37)
# (1039, 11.92)
# (1040, 6.33)
# (1041, 6.28)
# (1042, 6.1)
# (1043, 5.85)
# (1044, 5.86)
# (1045, 5.63)
# (1046, 5.25)
# (1047, 5.16)
# (1048, 5.0)
# (1049, 4.68)
# (1050, 4.65)
# (1051, 4.45)
# (1052, 4.5)
# (1053, 4.76)
# (1054, 11.92)
# (1055, 12.68)
# (1056, 6.09)
# (1057, 6.16)
# (1058, 6.22)
# (1059, 6.22)
# (1060, 6.16)
# (1061, 6.16)
# (1062, 5.63)
# (1063, 5.44)
# (1064, 5.34)
# (1065, 4.83)
# (1066, 4.59)
# (1067, 4.59)
# (1068, 4.61)
# (1069, 4.74)
# (1070, 12.3)
# (1071, 13.15)
# (1072, 6.85)
# (1073, 6.66)
# (1074, 6.47)
# (1075, 6.1)
# (1076, 6.1)
# (1077, 6.0)
# (1078, 5.65)
# (1079, 5.55)
# (1080, 5.16)
# (1081, 4.97)
# (1082, 4.81)
# (1083, 4.81)
# (1084, 4.56)
# (1085, 4.69)
# (1086, 11.85)
# (1087, 12.68)
# (1088, 6.78)
# (1089, 6.52)
# (1090, 6.62)
# (1091, 6.21)
# (1092, 5.96)
# (1093, 5.91)
# (1094, 5.91)
# (1095, 5.4)
# (1096, 4.87)
# (1097, 4.66)
# (1098, 4.71)
# (1099, 4.67)
# (1100, 4.68)
# (1101, 4.71)
# (1102, 12.11)
# (1103, 13.15)
# (1104, 6.38)
# (1105, 6.1)
# (1106, 6.0)
# (1107, 5.34)
# (1108, 5.53)
# (1109, 4.97)
# (1110, 4.79)
# (1111, 4.69)
# (1112, 4.68)
# (1113, 4.65)
# (1114, 4.65)
# (1115, 4.55)
# (1116, 4.55)
# (1117, 4.68)
# (1118, 11.78)
# (1119, 12.02)
# (1120, 6.61)
# (1121, 6.33)
# (1122, 6.19)
# (1123, 5.63)
# (1124, 5.34)
# (1125, 4.89)
# (1126, 4.87)
# (1127, 4.77)
# (1128, 4.94)
# (1129, 4.81)
# (1130, 4.81)
# (1131, 4.81)
# (1132, 4.69)
# (1133, 4.87)
# (1134, 11.83)
# (1135, 12.68)
# (1136, 6.85)
# (1137, 6.46)
# (1138, 6.38)
# (1139, 5.81)
# (1140, 5.94)
# (1141, 5.7)
# (1142, 5.71)
# (1143, 5.44)
# (1144, 5.06)
# (1145, 4.97)
# (1146, 4.87)
# (1147, 4.86)
# (1148, 4.69)
# (1149, 4.73)
# (1150, 11.83)
# (1151, 12.23)
# (1152, 6.38)
# (1153, 5.81)
# (1154, 5.86)
# (1155, 5.48)
# (1156, 5.31)
# (1157, 4.97)
# (1158, 4.64)
# (1159, 4.64)
# (1160, 4.56)
# (1161, 4.5)
# (1162, 4.38)
# (1163, 4.31)
# (1164, 4.31)
# (1165, 4.41)
# (1166, 11.69)
# (1167, 11.92)
# (1168, 4.87)
# (1169, 4.53)
# (1170, 5.34)
# (1171, 4.98)
# (1172, 5.06)
# (1173, 5.03)
# (1174, 5.53)
# (1175, 5.44)
# (1176, 5.41)
# (1177, 4.66)
# (1178, 4.69)
# (1179, 4.69)
# (1180, 4.64)
# (1181, 4.69)
# (1182, 11.94)
# (1183, 12.62)
# (1184, 6.09)
# (1185, 5.25)
# (1186, 5.16)
# (1187, 4.82)
# (1188, 4.87)
# (1189, 4.85)
# (1190, 4.69)
# (1191, 4.31)
# (1192, 4.22)
# (1193, 4.22)
# (1194, 4.22)
# (1195, 4.22)
# (1196, 4.12)
# (1197, 4.49)
# (1198, 11.54)
# (1199, 11.9)
# (1200, 6.1)
# (1201, 5.78)
# (1202, 6.0)
# (1203, 5.63)
# (1204, 5.81)
# (1205, 5.65)
# (1206, 5.63)
# (1207, 5.25)
# (1208, 4.87)
# (1209, 4.6)
# (1210, 4.63)
# (1211, 4.6)
# (1212, 4.59)
# (1213, 4.69)
# (1214, 12.04)
# (1215, 13.15)
# (1216, 6.28)
# (1217, 5.99)
# (1218, 5.75)
# (1219, 4.89)
# (1220, 4.87)
# (1221, 4.69)
# (1222, 4.94)
# (1223, 4.5)
# (1224, 4.59)
# (1225, 4.43)
# (1226, 4.47)
# (1227, 4.45)
# (1228, 4.4)
# (1229, 4.5)
# (1230, 11.56)
# (1231, 12.3)
# (1232, 6.24)
# (1233, 5.93)
# (1234, 5.06)
# (1235, 4.79)
# (1236, 4.61)
# (1237, 4.79)
# (1238, 4.61)
# (1239, 4.42)
# (1240, 4.5)
# (1241, 4.42)
# (1242, 4.42)
# (1243, 4.42)
# (1244, 4.4)
# (1245, 4.45)
# (1246, 11.55)
# (1247, 11.83)
# (1248, 6.08)
# (1249, 6.0)
# (1250, 5.67)
# (1251, 5.32)
# (1252, 4.5)
# (1253, 4.36)
# (1254, 4.39)
# (1255, 4.32)
# (1256, 4.32)
# (1257, 4.31)
# (1258, 4.24)
# (1259, 4.22)
# (1260, 4.22)
# (1261, 4.3)
# (1262, 11.55)
# (1263, 11.64)
# (1264, 6.38)
# (1265, 6.31)
# (1266, 5.81)
# (1267, 5.52)
# (1268, 4.96)
# (1269, 4.58)
# (1270, 4.31)
# (1271, 4.08)
# (1272, 4.09)
# (1273, 4.08)
# (1274, 3.75)
# (1275, 3.75)
# (1276, 4.03)
# (1277, 4.03)
# (1278, 11.12)
# (1279, 11.29)
# (1280, 5.91)
# (1281, 5.91)
# (1282, 5.5)
# (1283, 5.34)
# (1284, 4.69)
# (1285, 4.69)
# (1286, 4.36)
# (1287, 4.29)
# (1288, 4.5)
# (1289, 3.93)
# (1290, 3.28)
# (1291, 3.1)
# (1292, 3.09)
# (1293, 3.56)
# (1294, 11.73)
# (1295, 12.2)
# (1296, 5.4)
# (1297, 5.39)
# (1298, 5.39)
# (1299, 5.06)
# (1300, 4.03)
# (1301, 4.12)
# (1302, 3.75)
# (1303, 3.56)
# (1304, 3.56)
# (1305, 3.56)
# (1306, 3.28)
# (1307, 3.26)
# (1308, 3.37)
# (1309, 3.75)
# (1310, 11.21)
# (1311, 11.73)
# (1312, 6.0)
# (1313, 5.49)
# (1314, 4.99)
# (1315, 4.6)
# (1316, 4.27)
# (1317, 4.27)
# (1318, 4.21)
# (1319, 4.19)
# (1320, 4.12)
# (1321, 3.93)
# (1322, 3.84)
# (1323, 3.84)
# (1324, 3.75)
# (1325, 4.27)
# (1326, 11.36)
# (1327, 11.56)
# (1328, 6.38)
# (1329, 6.0)
# (1330, 5.16)
# (1331, 4.77)
# (1332, 4.2)
# (1333, 4.1)
# (1334, 4.03)
# (1335, 4.03)
# (1336, 3.88)
# (1337, 3.79)
# (1338, 3.76)
# (1339, 3.75)
# (1340, 3.75)
# (1341, 3.96)
# (1342, 11.17)
# (1343, 11.55)
# (1344, 6.12)
# (1345, 6.0)
# (1346, 5.43)
# (1347, 5.29)
# (1348, 5.36)
# (1349, 5.31)
# (1350, 4.97)
# (1351, 4.95)
# (1352, 4.69)
# (1353, 4.46)
# (1354, 4.42)
# (1355, 4.42)
# (1356, 4.42)
# (1357, 4.59)
# (1358, 11.74)
# (1359, 11.87)
# (1360, 6.1)
# (1361, 5.63)
# (1362, 5.18)
# (1363, 4.59)
# (1364, 4.76)
# (1365, 4.69)
# (1366, 4.69)
# (1367, 4.4)
# (1368, 4.4)
# (1369, 4.31)
# (1370, 4.22)
# (1371, 4.22)
# (1372, 4.3)
# (1373, 4.31)
# (1374, 11.57)
# (1375, 11.71)
# (1376, 5.63)
# (1377, 5.6)
# (1378, 5.63)
# (1379, 5.58)
# (1380, 5.7)
# (1381, 5.55)
# (1382, 5.12)
# (1383, 4.83)
# (1384, 4.42)
# (1385, 4.12)
# (1386, 4.03)
# (1387, 4.03)
# (1388, 4.03)
# (1389, 4.03)
# (1390, 11.17)
# (1391, 11.45)
# (1392, 4.5)
# (1393, 4.78)
# (1394, 5.18)
# (1395, 5.28)
# (1396, 5.55)
# (1397, 5.44)
# (1398, 5.37)
# (1399, 5.25)
# (1400, 5.44)
# (1401, 5.44)
# (1402, 5.37)
# (1403, 5.25)
# (1404, 4.31)
# (1405, 4.58)
# (1406, 11.73)
# (1407, 12.64)
# (1408, 6.44)
# (1409, 6.19)
# (1410, 5.67)
# (1411, 5.4)
# (1412, 5.16)
# (1413, 5.02)
# (1414, 4.88)
# (1415, 4.69)
# (1416, 4.69)
# (1417, 4.5)
# (1418, 4.25)
# (1419, 4.21)
# (1420, 4.21)
# (1421, 4.34)
# (1422, 11.33)
# (1423, 12.11)
# (1424, 5.79)
# (1425, 5.3)
# (1426, 5.25)
# (1427, 4.5)
# (1428, 4.49)
# (1429, 4.4)
# (1430, 4.51)
# (1431, 4.4)
# (1432, 4.4)
# (1433, 4.4)
# (1434, 4.4)
# (1435, 4.4)
# (1436, 4.39)
# (1437, 4.4)
# (1438, 11.69)
# (1439, 12.68)
# (1440, 6.75)
# (1441, 6.15)
# (1442, 6.43)
# (1443, 6.0)
# (1444, 5.93)
# (1445, 5.68)
# (1446, 5.72)
# (1447, 5.49)
# (1448, 5.11)
# (1449, 4.87)
# (1450, 4.63)
# (1451, 4.48)
# (1452, 4.4)
# (1453, 4.84)
# (1454, 12.12)
# (1455, 13.02)
# (1456, 5.63)
# (1457, 5.06)
# (1458, 4.69)
# (1459, 4.31)
# (1460, 4.38)
# (1461, 4.31)
# (1462, 4.61)
# (1463, 4.31)
# (1464, 4.5)
# (1465, 4.31)
# (1466, 4.31)
# (1467, 4.31)
# (1468, 4.3)
# (1469, 4.5)
# (1470, 11.63)
# (1471, 12.25)
# (1472, 6.01)
# (1473, 6.0)
# (1474, 6.05)
# (1475, 5.81)
# (1476, 5.56)
# (1477, 5.38)
# (1478, 5.44)
# (1479, 5.06)
# (1480, 4.97)
# (1481, 4.69)
# (1482, 4.4)
# (1483, 4.4)
# (1484, 4.32)
# (1485, 4.4)
# (1486, 11.42)
# (1487, 12.02)
# (1488, 4.61)
# (1489, 3.75)
# (1490, 4.56)
# (1491, 3.93)
# (1492, 4.31)
# (1493, 4.17)
# (1494, 4.5)
# (1495, 4.12)
# (1496, 3.89)
# (1497, 3.89)
# (1498, 3.89)
# (1499, 3.89)
# (1500, 3.79)
# (1501, 4.11)
# (1502, 10.95)
# (1503, 11.37)
# (1504, 4.8)
# (1505, 4.69)
# (1506, 5.06)
# (1507, 4.88)
# (1508, 5.16)
# (1509, 5.08)
# (1510, 5.52)
# (1511, 5.31)
# (1512, 5.18)
# (1513, 5.06)
# (1514, 4.69)
# (1515, 4.69)
# (1516, 5.06)
# (1517, 5.08)
# (1518, 12.11)
# (1519, 12.34)
# (1520, 4.87)
# (1521, 4.78)
# (1522, 4.78)
# (1523, 4.87)
# (1524, 5.25)
# (1525, 5.16)
# (1526, 5.44)
# (1527, 5.27)
# (1528, 5.25)
# (1529, 4.69)
# (1530, 4.87)
# (1531, 5.04)
# (1532, 4.69)
# (1533, 4.81)
# (1534, 12.02)
# (1535, 12.57)
# (1536, 6.19)
# (1537, 6.0)
# (1538, 5.9)
# (1539, 5.59)
# (1540, 5.44)
# (1541, 5.44)
# (1542, 5.63)
# (1543, 5.16)
# (1544, 5.02)
# (1545, 4.69)
# (1546, 4.78)
# (1547, 4.71)
# (1548, 4.5)
# (1549, 5.16)
# (1550, 12.2)
# (1551, 12.96)
# (1552, 5.9)
# (1553, 5.36)
# (1554, 5.15)
# (1555, 4.69)
# (1556, 4.69)
# (1557, 4.59)
# (1558, 4.77)
# (1559, 4.64)
# (1560, 4.57)
# (1561, 4.46)
# (1562, 4.35)
# (1563, 4.5)
# (1564, 4.35)
# (1565, 4.52)
# (1566, 11.59)
# (1567, 12.39)
# (1568, 5.54)
# (1569, 4.97)
# (1570, 5.44)
# (1571, 4.87)
# (1572, 5.06)
# (1573, 4.79)
# (1574, 5.08)
# (1575, 4.59)
# (1576, 4.87)
# (1577, 4.59)
# (1578, 4.69)
# (1579, 4.59)
# (1580, 4.7)
# (1581, 5.16)
# (1582, 12.25)
# (1583, 13.05)
# (1584, 6.75)
# (1585, 6.34)
# (1586, 6.0)
# (1587, 5.44)
# (1588, 5.63)
# (1589, 5.34)
# (1590, 5.59)
# (1591, 5.16)
# (1592, 5.06)
# (1593, 4.65)
# (1594, 4.62)
# (1595, 4.54)
# (1596, 4.41)
# (1597, 4.56)
# (1598, 11.73)
# (1599, 12.96)
# (1600, 6.33)
# (1601, 6.3)
# (1602, 6.28)
# (1603, 6.15)
# (1604, 5.74)
# (1605, 5.49)
# (1606, 5.64)
# (1607, 5.25)
# (1608, 5.25)
# (1609, 4.38)
# (1610, 4.5)
# (1611, 4.33)
# (1612, 4.22)
# (1613, 4.31)
# (1614, 11.17)
# (1615, 11.62)
# (1616, 5.16)
# (1617, 5.06)
# (1618, 5.39)
# (1619, 5.16)
# (1620, 5.52)
# (1621, 5.44)
# (1622, 5.33)
# (1623, 5.16)
# (1624, 4.73)
# (1625, 4.42)
# (1626, 4.41)
# (1627, 4.4)
# (1628, 4.22)
# (1629, 4.41)
# (1630, 11.83)
# (1631, 12.2)
# (1632, 5.66)
# (1633, 4.87)
# (1634, 4.69)
# (1635, 4.49)
# (1636, 4.46)
# (1637, 4.46)
# (1638, 4.41)
# (1639, 4.24)
# (1640, 4.31)
# (1641, 4.08)
# (1642, 4.4)
# (1643, 4.08)
# (1644, 4.12)
# (1645, 4.12)
# (1646, 11.37)
# (1647, 11.94)
# (1648, 5.63)
# (1649, 4.85)
# (1650, 4.48)
# (1651, 4.24)
# (1652, 4.26)
# (1653, 4.23)
# (1654, 4.24)
# (1655, 4.22)
# (1656, 4.17)
# (1657, 4.12)
# (1658, 4.12)
# (1659, 4.12)
# (1660, 4.03)
# (1661, 4.19)
# (1662, 11.36)
# (1663, 11.58)
# (1664, 5.16)
# (1665, 4.31)
# (1666, 4.36)
# (1667, 4.17)
# (1668, 4.18)
# (1669, 4.18)
# (1670, 4.31)
# (1671, 4.16)
# (1672, 4.15)
# (1673, 4.14)
# (1674, 4.11)
# (1675, 4.11)
# (1676, 4.03)
# (1677, 4.16)
# (1678, 11.27)
# (1679, 11.36)
